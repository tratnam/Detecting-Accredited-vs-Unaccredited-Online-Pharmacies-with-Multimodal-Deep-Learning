# %% [markdown]
# ## Web Scrape for Accredited Pharmacies

# %%
import pandas as pd
import shutil
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pdb
from urllib.request import urlopen, Request
import requests
from IPython.core.display import HTML

# %%
df = pd.read_csv('Accredited Digital Pharmacies _ National Association of Boards of Pharmacy.csv')
df['url'] = df['Website'].str.strip()
df['u2'] = df['url'].str.replace(r'\n\n\n\tif', ' ')
df['urls'] = df['u2'].str.split(' ').str[0]
df['Name'] = df['BusinessName_PharmacyName'].str.split('\n\t\t').str[1]
gg = df[['Name','urls']]

# strip https:// bc they only occur for some of the urls
gg['urls'] = gg['urls'].str.strip('https://')
gg = gg.iloc[: , 0:]
gg.to_csv('good_guys.csv',index = False)
gg = gg.drop([2, 46, 78]) ##### I DROPPED THREE ROWS THAT WERE MISSING URLs!!!!
gg.tail(10)

# add the https:// part back in for all of them
gg['link'] = 'https://' + gg['urls'].astype(str)
raw_links = gg['link'].tolist()
raw_links
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# ['https://acariahealth.envolvehealth.com',
#  'https://www.accredo.pharmacy',
#  'https://www.alphascriptrx.com',
#  'https://alto.com',
#  'https://www.amberpharmacy.com',
#  'https://www.medvantxrx.com',
#  'https://www.aoncology.com',
#  'https://www.citizenpharmacy.com',
#  'https://www.bioplusrx.com',
#  'https://www.birdirx.com',
#  'https://www.cornerstonehealthsolutions.org',
#  'https://www.cfspharmacy.pharmacy',
#  'https://www.caremark.com',
#  'https://www.carepointrx.com',
#  'https://redrockhome.pharmacy',
#  'https://www.centerwellpharmacy.com',
#  'https://www.carolinacarerx.org',
#  'https://www.costco.com',
#  'https://www.curanthealth.com',
#  'https://www.ccsmed.com',
#  'https://www.divvydose.com',
#  'https://www.friendswoodhealthmartpharmacy.com',
#  'https://eaglepharmacy.com',
#  'https://envisionpharmacies.com',
#  'https://www.express-scripts.com',
#  'https://www.essentiahealth.org',
#  'https://www.ecspecialtyrx.com',
#  'https://rosh.pharmacy',
#  'https://gentryhealthservices.com',
#  'https://www.dfwwellnesspharmacy.com',
#  'https://ameripharma.u',
#  'https://www.harristeeter.com',
#  'https://www.hometownpharmacy.com',
#  'https://www.healthwarehouse.com',
#  'https://www.hy-vee.com',
#  'https://www.hvrxsolutions.com',
#  'https://intermountainhealthcare.org/services/pharmacy',
#  'https://www.iuhealth.org/patients/pharmacie',
#  'https://www.icsrx.com',
#  'https://www.memorial.pharmacy',
#  'https://www.kmart.com',
#  'https://www.magellanrx.pharmacy',
#  'https://www.medimpact.com',
#  'https://www.meijer.com',
#  'https://www.geniusrx.com',
#  'https://www.thepillclub.com',
#  'https://www.noblehealthservices.com',
#  'https://www.northcoastmed.com',
#  'https://www.onco360.com',
#  'https://www.optumrx.com',
#  'https://www.orsinihealthcare.com',
#  'https://www.pantherxrare.com',
#  'https://www.rosemontspecialtyrx.com',
#  'https://www.mintrxpharmacy.com',
#  'https://www.amazon.com',
#  'https://ruepill.pharmacy',
#  'https://www.powerhousepharmacy.com',
#  'https://www.ridgeway.pharmacy',
#  'https://www.blueskyspecialtypharmacy.com',
#  'https://www.rxoutreach.org',
#  'https://www.flcancer.com',
#  'https://www.stpeterscommunitypharmacy.com',
#  'https://www.schrafts2.com',
#  'https://www.scriptsrxpharmacy.com',
#  'https://www.senderrarx.com',
#  'https://medhope.pharmacy',
#  'https://www.solerarx.com',
#  'https://www.sortpak.com',
#  'https://www.smrtrx.ne',
#  'https://www.synergenrx.com',
#  'https://www.bakersplus.com',
#  'https://metrohealth.pharmacy',
#  'https://mylocalrx.org',
#  'https://www.hopesp.com',
#  'https://www.medicorx.com',
#  'https://aging.depotdrug.com',
#  'https://www.usmed-rx.com',
#  'https://www.vascorx.com',
#  'https://rescriptions.wakehealth.edu',
#  'https://www.walmart.com/cp/pharmacy/5431',
#  'https://www.walgreens.com',
#  'https://www.weismarkets.com',
#  'https://www.welldynerx.com',
#  'https://www.yourrxpharmacy.com']

# %% [markdown]
# ### List of URLs
#
# The ones commented out return various types of errors. Initially broke them out into chunks to see which ones were bad, some of them couldn't be looped and had to manually go through them.

# %%
d1 = ['https://acariahealth.envolvehealth.com',
 'https://www.accredo.pharmacy',
 'https://www.alphascriptrx.com',
 'https://alto.com',
 'https://www.amberpharmacy.com',
# 'https://www.medvantxrx.com', RETURNS RESPONSE: 503
 'https://www.aoncology.com',
 'https://www.citizenpharmacy.com',
 'https://www.bioplusrx.com',
 'https://www.birdirx.com',
 'https://www.cornerstonehealthsolutions.org',
 'https://www.cfspharmacy.pharmacy',
 'https://www.caremark.com',
 'https://www.carepointrx.com',
# 'https://redrockhome.pharmacy', RETURNS SSLERROR
 'https://www.centerwellpharmacy.com',
 'https://www.carolinacarerx.org',
# 'https://www.costco.com', KERNAL KEEPS RUNNING, NOT SURE WHAT THE ERROR IS. DOESN'T OUTPUT ANYTHING.
 'https://www.curanthealth.com',
 'https://www.ccsmed.com',
 'https://www.divvydose.com',
 'https://www.friendswoodhealthmartpharmacy.com',
 'https://eaglepharmacy.com',
# 'https://envisionpharmacies.com', RETURNS SSLERROR
 'https://www.express-scripts.com',
 'https://www.essentiahealth.org',
 'https://www.ecspecialtyrx.com',
# 'https://rosh.pharmacy', RETURNS CONNECTIONERROR
 'https://gentryhealthservices.com',
 'https://www.dfwwellnesspharmacy.com',
# 'https://ameripharma.u', RETURNS CONNECTIONERROR
# 'https://www.harristeeter.com', KERNAL KEEPS RUNNING, NOT SURE WHAT THE ERROR IS. DOESN'T OUTPUT ANYTHING.
 'https://www.hometownpharmacy.com',
 'https://www.healthwarehouse.com',
 'https://www.hy-vee.com',
 'https://www.hvrxsolutions.com',
 'https://intermountainhealthcare.org/services/pharmacy',
# 'https://www.iuhealth.org/patients/pharmacie', RETURNS RESPONSE: 404
# 'https://www.icsrx.com', RETURNS SSLERROR
# 'https://www.memorial.pharmacy', RETURNS CONNECTIONERROR
# 'https://www.kmart.com', KERNAL KEEPS RUNNING, NOT SURE WHAT THE ERROR IS. DOESN'T OUTPUT ANYTHING.
 'https://www.magellanrx.pharmacy', 
 'https://www.medimpact.com',
# 'https://www.meijer.com', KERNAL KEEPS RUNNING, NOT SURE WHAT THE ERROR IS. DOESN'T OUTPUT ANYTHING.
 'https://www.geniusrx.com',
 'https://www.thepillclub.com',
# 'https://www.noblehealthservices.com', RETURNS SSLERROR
 'https://www.northcoastmed.com',
 'https://www.onco360.com',
 'https://www.optumrx.com',
 'https://www.orsinihealthcare.com',
 'https://www.pantherxrare.com',
# 'https://www.rosemontspecialtyrx.com', RETURNS RESPONSE: 500
 'https://www.mintrxpharmacy.com',
 'https://www.amazon.com',
# 'https://ruepill.pharmacy', RETURNS CONNECTIONERROR
 'https://www.powerhousepharmacy.com',
 'https://www.ridgeway.pharmacy',
 'https://www.blueskyspecialtypharmacy.com',
 'https://www.rxoutreach.org',
 'https://www.flcancer.com',
 'https://www.stpeterscommunitypharmacy.com',
 'https://www.schrafts2.com',
 'https://www.scriptsrxpharmacy.com',
 'https://www.senderrarx.com',
# 'https://medhope.pharmacy', RETURNS CONNECTIONERROR
 'https://www.solerarx.com',
 'https://www.sortpak.com',
# 'https://www.smrtrx.ne', RETURNS CONNECTIONERROR
 'https://www.synergenrx.com',
# 'https://www.bakersplus.com', KERNAL KEEPS RUNNING, NOT SURE WHAT THE ERROR IS. DOESN'T OUTPUT ANYTHING.
 'https://metrohealth.org/pharmacy',
 'https://mylocalrx.org',
 'https://www.hopesp.com',
 'https://www.medicorx.com',
# 'https://aging.depotdrug.com', RETURNS CONNECTIONERROR
 'https://www.usmed-rx.com',
 'https://www.vascorx.com',
# 'https://rescriptions.wakehealth.edu', RETURNS CONNECTIONERROR
 'https://www.walmart.com/cp/pharmacy/5431',
 'https://www.walgreens.com',
# 'https://www.weismarkets.com', RETURNS RESPONSE: 403
 'https://www.welldynerx.com',
 'https://www.yourrxpharmacy.com']

# %%
### test

website = 'https://acariahealth.envolvehealth.com'
headers = {'user-agent': 'ds6050 (fdf7gn@virginia.edu)'}
r = requests.get(website, headers=headers)
r
# Out:
# <Response [200]>

# %%
def good_urls(url):
    headers = {'user-agent': 'ds6050 (fdf7gn@virginia.edu)'}
    r = requests.get(url, headers=headers)
    #print(r)
    if r.status_code == 200:
        return url 

good_urls(website)
# Out:
# 'https://acariahealth.envolvehealth.com'

# %%
url_list = []
for d in d1:
    links = good_urls(d)
    url_list.append(links)

# %% [markdown]
# Creates a list of urls that actually work

# %%
url_list
# Out:
# ['https://acariahealth.envolvehealth.com',
#  'https://www.accredo.pharmacy',
#  'https://www.alphascriptrx.com',
#  'https://alto.com',
#  'https://www.amberpharmacy.com',
#  'https://www.aoncology.com',
#  'https://www.citizenpharmacy.com',
#  'https://www.bioplusrx.com',
#  'https://www.birdirx.com',
#  'https://www.cornerstonehealthsolutions.org',
#  'https://www.cfspharmacy.pharmacy',
#  'https://www.caremark.com',
#  'https://www.carepointrx.com',
#  'https://www.centerwellpharmacy.com',
#  'https://www.carolinacarerx.org',
#  'https://www.curanthealth.com',
#  'https://www.ccsmed.com',
#  'https://www.divvydose.com',
#  'https://www.friendswoodhealthmartpharmacy.com',
#  'https://eaglepharmacy.com',
#  'https://www.express-scripts.com',
#  'https://www.essentiahealth.org',
#  'https://www.ecspecialtyrx.com',
#  'https://gentryhealthservices.com',
#  'https://www.dfwwellnesspharmacy.com',
#  'https://www.hometownpharmacy.com',
#  'https://www.healthwarehouse.com',
#  'https://www.hy-vee.com',
#  'https://www.hvrxsolutions.com',
#  'https://intermountainhealthcare.org/services/pharmacy',
#  'https://www.magellanrx.pharmacy',
#  'https://www.medimpact.com',
#  'https://www.geniusrx.com',
#  'https://www.thepillclub.com',
#  'https://www.northcoastmed.com',
#  'https://www.onco360.com',
#  'https://www.optumrx.com',
#  'https://www.orsinihealthcare.com',
#  'https://www.pantherxrare.com',
#  'https://www.mintrxpharmacy.com',
#  'https://www.amazon.com',
#  'https://www.powerhousepharmacy.com',
#  'https://www.ridgeway.pharmacy',
#  'https://www.blueskyspecialtypharmacy.com',
#  'https://www.rxoutreach.org',
#  'https://www.flcancer.com',
#  'https://www.stpeterscommunitypharmacy.com',
#  'https://www.schrafts2.com',
#  'https://www.scriptsrxpharmacy.com',
#  'https://www.senderrarx.com',
#  'https://www.solerarx.com',
#  'https://www.sortpak.com',
#  'https://www.synergenrx.com',
#  'https://metrohealth.org/pharmacy',
#  'https://mylocalrx.org',
#  'https://www.hopesp.com',
#  'https://www.medicorx.com',
#  'https://www.usmed-rx.com',
#  'https://www.vascorx.com',
#  'https://www.walmart.com/cp/pharmacy/5431',
#  'https://www.walgreens.com',
#  'https://www.welldynerx.com',
#  'https://www.yourrxpharmacy.com']

# %% [markdown]
# ### Loop through url_list to scrape text & images

# %%
### TEST
#url = 'https://acariahealth.envolvehealth.com' #'https://www.carolinacarerx.org'
#image_url = 'https://www.carolinacarerx.org'

def url_to_df(url):
    try:
        html = urlopen(url)
        headers = {'user-agent': 'Mozilla/5.0'}
        page = requests.get(url, headers)
        soup = BeautifulSoup(page.content,'html.parser')
        body = soup.body
        header = soup.header
        footer = soup.footer
        
        head = []
        for h in header.strings:
            head.append(h)
        
        foot = []
        for f in footer.strings:
            foot.append(f)
        
        text = []
        for s in body.strings:
            text.append(s)
        
        images = []    
        for item in soup.find_all('img'):
            images.append(url + item['src'])
    
        image2 = []
        for item in soup.find_all('img'):
            image2.append(item['src'])
        
        url_df = pd.DataFrame(data= {'url':[url],'text':[text], 'header':[head],'footer':[foot],
                                     'image_url':[images], 'image_source':[image2]})
        return url_df
    except: 
        pass

# %%
df = pd.DataFrame()

for u in url_list:
    dictObj =url_to_df(u)
    df = df.append(dictObj) # can we suppress/ignore the deprecation messages ??
# Out:
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.

# %%
# df

# %%
df = df.reset_index()
df
# Out:
#     index                                                url  \
# 0       0             https://acariahealth.envolvehealth.com
# 1       0                       https://www.accredo.pharmacy
# 2       0                      https://www.alphascriptrx.com
# 3       0                          https://www.aoncology.com
# 4       0         https://www.cornerstonehealthsolutions.org
# 5       0                       https://www.curanthealth.com
# 6       0      https://www.friendswoodhealthmartpharmacy.com
# 7       0                          https://eaglepharmacy.com
# 8       0                    https://www.express-scripts.com
# 9       0                     https://www.essentiahealth.org
# 10      0                https://www.dfwwellnesspharmacy.com
# 11      0  https://intermountainhealthcare.org/services/p...
# 12      0                           https://www.geniusrx.com
# 13      0                   https://www.orsinihealthcare.com
# 14      0                       https://www.pantherxrare.com
# 15      0                     https://www.mintrxpharmacy.com
# 16      0                           https://www.flcancer.com
# 17      0                  https://www.scriptsrxpharmacy.com
# 18      0                         https://www.senderrarx.com
# 19      0                         https://www.synergenrx.com
# 20      0                              https://mylocalrx.org
# 21      0                            https://www.vascorx.com
# 22      0                          https://www.walgreens.com
#
#                                                  text  \
# 0                                    [\n, \n, \n, \n]
# 1   [\n, \n            Skip to main content\n     ...
# 2   [\n, \n, \n, \n, \n, \n, (650) 412-4530, \n, p...
# 3   [\n, \n    <div class="wpautoterms-update-noti...
# 4   [\n, Skip to main content\n    ,  , \n, \n, \n...
# 5   [\n,  , \n, \n, \n, \n, Join Our Team, \n, \n,...
# 6   [\n, \n, \r\n\t\tSkip to content, \n, \n, \n, ...
# 7   [\n, \n, We are currently experiencing issues ...
# 8   [ ,  Skip to main content ,  , Menu,  ,  ,  , ...
# 9   [\n, \n,  COVID-19 Update, \n, Masks must stil...
# 10  [\n, \n, \n, \r\n    Curbside Pick-Up and No-C...
# 11  [\n, \n, \n, \n, \n, Skip to main content, \n,...
# 12  [\n,  ,  , \n, \n, \n, \n, Looking to save up ...
# 13  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...
# 14  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...
# 15  [\n, \n, \n, \n, \n, \n, Skip to main content,...
# 16  [\n, \n, \n, \n, \n, \r\n    window._monsido =...
# 17  [\n, \n    var bodyCacheable = true;\n    \n  ...
# 18  [\n, \n, \n, \n, \n, Skip to the main content....
# 19  [\n, \n    var bodyCacheable = true;\n    \n  ...
# 20  [\n, \n, \n, \n, \n, \n, \n\t\tSkip to Main Co...
# 21  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...
# 22  [\n, \n                Skip to main content\n ...
#
#                                                header  \
# 0   [\n, \n, \n, \n, \n, \n, \n, Home, \n, Contact...
# 1   [\n, \n, \n, \n, \n, \n, Orders may be delayed...
# 2   [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, Patie...
# 3   [\n, \n, \n, For Patients, \n, Careers, \n, Bl...
# 4   [\n, \n, \n,  , \n, \n, \n, \n, \n, \n, \n, \n...
# 5   [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, Home,...
# 6   [\n, \n, \n, \n, \n, \n, \n,  , \n, \n, \n, \n...
# 7   [We are currently experiencing issues with our...
# 8   [ , Menu,  ,  ,  , Log In,  , Register,  ,  , ...
# 9   [\n, \n, \n, \n, \n, Your Location: , Set Your...
# 10  [\n, \n, \n, \n, \n, \n, \n, \n, \n,  , \n, 85...
# 11  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...
# 12  [\n, \n, \n, Looking to save up to 80% on your...
# 13  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...
# 14  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...
# 15  [\n, Skip to main content, \n, Skip to footer ...
# 16  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...
# 17  [Map Pin, \n, \n, \n, \n, \n, Chicago: (800) 2...
# 18  [\n, \n, \n, Skip to the main content., \n, \n...
# 19  [Home, Specialties, Providers, Patients, Pharm...
# 20  [\n, \n, \n, 800.923.9394, \n, \n, Para Españo...
# 21  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, T...
# 22  [\r\n  .global_nav_text {\r\n    /*font-family...
#
#                                                footer  \
# 0   [\n, \n, \n, \n, \n, \n, Locations, \n, Referr...
# 1   [\n, \n, \n, \n, \n, \n, \n, \n, \n           ...
# 2   [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...
#
# 13  [https://www.orsinispecialtypharmacy.com/hs-fs...
# 14  [https://www.pantherxrare.com/wp-content/theme...
# 15  [https://www.facebook.com/tr?id=19764215183921...
# 16  [https://flcancer.com/app/uploads/2021/06/2017...
# 17  [https://static.wixstatic.com/media/f44edb_33a...
# 18  [https://www.senderrarx.com/hs-fs/hubfs/Sender...
# 19  [https://static.wixstatic.com/media/35816e_e98...
# 20  [https://www.trilliumhealth.pharmacy/images/lo...
# 21  [https://vascorx.com/wp-content/themes/vascorx...
# 22  [/images/adaptive/sp/giftbox_22x20.png, data:i...

# %%
import xml.etree.ElementTree as ET
import io
import requests
from bs4 import BeautifulSoup
import http.client
import mimetypes
import json
import re

# %%
def zipLookup(zcode):
  root = ET.Element("CityStateLookupRequest", USERID="847WIPRO1073")
  m1 = ET.SubElement(root, "ZipCode", ID="0")
  ET.SubElement(m1, "Zip5").text = zcode
  tree = ET.ElementTree(root)
  out = io.BytesIO()
  tree.write(out)
  zip_xml = out.getvalue().decode()
  site = f"https://secure.shippingapis.com/ShippingAPITest.dll?API=CityStateLookup&XML={zip_xml}"
  response = requests.get(site)
  r = BeautifulSoup(response.text, 'html')
  city = r.find_all('city')
  #print(city)
  if not city:
     z = 'no'
  else:
     z = 'yes'
  return z

# %%
df['html'] = df['text'] + df['footer'] + df['header']
df
# Out:
#     index                                                url  \
# 0       0             https://acariahealth.envolvehealth.com
# 1       0                       https://www.accredo.pharmacy
# 2       0                      https://www.alphascriptrx.com
# 3       0                          https://www.aoncology.com
# 4       0         https://www.cornerstonehealthsolutions.org
# 5       0                       https://www.curanthealth.com
# 6       0      https://www.friendswoodhealthmartpharmacy.com
# 7       0                          https://eaglepharmacy.com
# 8       0                    https://www.express-scripts.com
# 9       0                     https://www.essentiahealth.org
# 10      0                https://www.dfwwellnesspharmacy.com
# 11      0  https://intermountainhealthcare.org/services/p...
# 12      0                           https://www.geniusrx.com
# 13      0                   https://www.orsinihealthcare.com
# 14      0                       https://www.pantherxrare.com
# 15      0                     https://www.mintrxpharmacy.com
# 16      0                           https://www.flcancer.com
# 17      0                  https://www.scriptsrxpharmacy.com
# 18      0                         https://www.senderrarx.com
# 19      0                         https://www.synergenrx.com
# 20      0                              https://mylocalrx.org
# 21      0                            https://www.vascorx.com
# 22      0                          https://www.walgreens.com
#
#                                                  text  \
# 0                                    [\n, \n, \n, \n]
# 1   [\n, \n            Skip to main content\n     ...
# 2   [\n, \n, \n, \n, \n, \n, (650) 412-4530, \n, p...
# 3   [\n, \n    <div class="wpautoterms-update-noti...
# 4   [\n, Skip to main content\n    ,  , \n, \n, \n...
# 5   [\n,  , \n, \n, \n, \n, Join Our Team, \n, \n,...
# 6   [\n, \n, \r\n\t\tSkip to content, \n, \n, \n, ...
# 7   [\n, \n, We are currently experiencing issues ...
# 8   [ ,  Skip to main content ,  , Menu,  ,  ,  , ...
# 9   [\n, \n,  COVID-19 Update, \n, Masks must stil...
# 10  [\n, \n, \n, \r\n    Curbside Pick-Up and No-C...
# 11  [\n, \n, \n, \n, \n, Skip to main content, \n,...
# 12  [\n,  ,  , \n, \n, \n, \n, Looking to save up ...
# 13  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...
# 14  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...
#
[\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...
# 14  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...
# 15  [\n, \n, \n, \n, \n, \n, Skip to main content,...
# 16  [\n, \n, \n, \n, \n, \r\n    window._monsido =...
# 17  [\n, \n    var bodyCacheable = true;\n    \n  ...
# 18  [\n, \n, \n, \n, \n, Skip to the main content....
# 19  [\n, \n    var bodyCacheable = true;\n    \n  ...
# 20  [\n, \n, \n, \n, \n, \n, \n\t\tSkip to Main Co...
# 21  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...
# 22  [\n, \n                Skip to main content\n ...

# %%
search=[]
for i in df['html']:
  k = re.findall('(\d{5})([- ])?(\d{4})?', str(i))
  
  if k:
    zip = []
    for z in k:
      zip.append(zipLookup(z[0]))
    if 'yes' in zip:
        search.append('yes')
    else:
        search.append('no')
  else:
    search.append('no')
df['zipcode'] = search

# %%
df
# Out:
#     index                                                url  \
# 0       0             https://acariahealth.envolvehealth.com
# 1       0                       https://www.accredo.pharmacy
# 2       0                      https://www.alphascriptrx.com
# 3       0                          https://www.aoncology.com
# 4       0         https://www.cornerstonehealthsolutions.org
# 5       0                       https://www.curanthealth.com
# 6       0      https://www.friendswoodhealthmartpharmacy.com
# 7       0                          https://eaglepharmacy.com
# 8       0                    https://www.express-scripts.com
# 9       0                     https://www.essentiahealth.org
# 10      0                https://www.dfwwellnesspharmacy.com
# 11      0  https://intermountainhealthcare.org/services/p...
# 12      0                           https://www.geniusrx.com
# 13      0                   https://www.orsinihealthcare.com
# 14      0                       https://www.pantherxrare.com
# 15      0                     https://www.mintrxpharmacy.com
# 16      0                           https://www.flcancer.com
# 17      0                  https://www.scriptsrxpharmacy.com
# 18      0                         https://www.senderrarx.com
# 19      0                         https://www.synergenrx.com
# 20      0                              https://mylocalrx.org
# 21      0                            https://www.vascorx.com
# 22      0                          https://www.walgreens.com
#
#                                                  text  \
# 0                                    [\n, \n, \n, \n]
# 1   [\n, \n            Skip to main content\n     ...
# 2   [\n, \n, \n, \n, \n, \n, (650) 412-4530, \n, p...
# 3   [\n, \n    <div class="wpautoterms-update-noti...
# 4   [\n, Skip to main content\n    ,  , \n, \n, \n...
# 5   [\n,  , \n, \n, \n, \n, Join Our Team, \n, \n,...
# 6   [\n, \n, \r\n\t\tSkip to content, \n, \n, \n, ...
# 7   [\n, \n, We are currently experiencing issues ...
# 8   [ ,  Skip to main content ,  , Menu,  ,  ,  , ...
# 9   [\n, \n,  COVID-19 Update, \n, Masks must stil...
# 10  [\n, \n, \n, \r\n    Curbside Pick-Up and No-C...
# 11  [\n, \n, \n, \n, \n, Skip to main content, \n,...
# 12  [\n,  ,  , \n, \n, \n, \n, Looking to save up ...
# 13  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...
# 14  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...
# 15  [\n, \n, \n, \n, \n, \n, Skip to main content,...
# 16  [\n, \n, \n, \n, \n, \r\n    window._monsido =...
# 17  [\n, \n    var bodyCacheable = true;\n    \n  ...
# 18  [\n, \n, \n, \n, \n, Skip to the main content....
# 19  [\n, \n    var bodyCacheable = true;\n    \n  ...
# 20  [\n, \n, \n, \n, \n, \n, \n\t\tSkip to Main Co...
# 21  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...
#
# 9   [https://www.essentiahealth.org/app/files/publ...
# 10  [https://www.dfwwellnesspharmacy.comhttps://ww...
# 11  [https://intermountainhealthcare.org/services/...
# 12  [https://www.geniusrx.com/assets/images/genius...
# 13  [https://www.orsinihealthcare.comhttps://www.o...
# 14  [https://www.pantherxrare.comhttps://www.panth...
# 15  [https://www.mintrxpharmacy.comhttps://www.fac...
# 16  [https://www.flcancer.comhttps://flcancer.com/...
# 17  [https://www.scriptsrxpharmacy.comhttps://stat...
# 18  [https://www.senderrarx.comhttps://www.senderr...
# 19  [https://www.synergenrx.comhttps://static.wixs...
# 20  [https://mylocalrx.orghttps://www.trilliumheal...
# 21  [https://www.vascorx.comhttps://vascorx.com/wp...
# 22  [https://www.walgreens.com/images/adaptive/sp/...
#
#                                          image_source  \
# 0   [/content/dam/centene/envolve-pharmacy-solutio...
# 1   [https://esi-drupal-cdn.s3.amazonaws.com/accre...
# 2   [......
# 3   [https://dc.ads.linkedin.com/collect/?pid=9449...
# 4   [/themes/contrib/emulsify/images/logos/logo.sv...
# 5   [https://curanthealth.com/wp-content/uploads/2...
# 6   [https://www.friendswoodhealthmartpharmacy.com...
# 7   [https://global-uploads.webflow.com/59516e6b55...
# 8   [/themes/custom/dsf/img/ui/1x1-transparent.gif...
# 9   [/app/files/public/2897/Essentia-Health-Logo.s...
# 10  [https://www.dfwwellnesspharmacy.com/wp-conten...
# 11  [/-/media/images/global/1-1/woman-on-a-laptop....
# 12  [/assets/images/geniusrx-logo.png, /assets/ima...
# 13  [https://www.orsinispecialtypharmacy.com/hs-fs...
# 14  [https://www.pantherxrare.com/wp-content/theme...
# 15  [https://www.facebook.com/tr?id=19764215183921...
# 16  [https://flcancer.com/app/uploads/2021/06/2017...
# 17  [https://static.wixstatic.com/media/f44edb_33a...
# 18  [https://www.senderrarx.com/hs-fs/hubfs/Sender...
# 19  [https://static.wixstatic.com/media/35816e_e98...
# 20  [https://www.trilliumhealth.pharmacy/images/lo...
# 21  [https://vascorx.com/wp-content/themes/vascorx...
# 22  [/images/adaptive/sp/giftbox_22x20.png, data:i...
#
#                                                  html zipcode
# 0   [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, Locat...      no
# 1   [\n, \n            Skip to main content\n     ...     yes
# 2   [\n, \n, \n, \n, \n, \n, (650) 412-4530, \n, p...     yes
# 3   [\n, \n    <div class="wpautoterms-update-noti...      no
# 4   [\n, Skip to main content\n    ,  , \n, \n, \n...     yes
# 5   [\n,  , \n, \n, \n, \n, Join Our Team, \n, \n,...     yes
# 6   [\n, \n, \r\n\t\tSkip to content, \n, \n, \n, ...     yes
# 7   [\n, \n, We are currently experiencing issues ...     yes
# 8   [ ,  Skip to main content ,  , Menu,  ,  ,  , ...     yes
# 9   [\n, \n,  COVID-19 Update, \n, Masks must stil...      no
# 10  [\n, \n, \n, \r\n    Curbside Pick-Up and No-C...     yes
# 11  [\n, \n, \n, \n, \n, Skip to main content, \n,...     yes
# 12  [\n,  ,  , \n, \n, \n, \n, Looking to save up ...     yes
# 13  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...     yes
# 14  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...     yes
# 15  [\n, \n, \n, \n, \n, \n, Skip to main content,...     yes
# 16  [\n, \n, \n, \n, \n, \r\n    window._monsido =...      no
# 17  [\n, \n    var bodyCacheable = true;\n    \n  ...     yes
# 18  [\n, \n, \n, \n, \n, Skip to the main content....     yes
# 19  [\n, \n    var bodyCacheable = true;\n    \n  ...     yes
# 20  [\n, \n, \n, \n, \n, \n, \n\t\tSkip to Main Co...      no
# 21  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...     yes
# 22  [\n, \n                Skip to main content\n ...     yes

# %%
import http.client
import mimetypes
import json
def phoneLookup(contact):
  conn = http.client.HTTPSConnection("api.veriphone.io")
  phone = contact
  key = '9FF3B68481994437A10B698E6EB5D5A4'
  default_country = '+1'
  url = '/v2/verify?phone='+phone+'&key='+key+'&default_country='+default_country
  conn.request("GET", url)
  res = conn.getresponse()
  datajs = res.read()
  data = json.loads(datajs.decode("utf-8"))
  return data['phone_valid']

# %%
search = []
for i in df['html']:
  k = re.findall(r'[\+\(]?[1-9][0-9 .\-\(\)]{8,}[0-9]', str(i))
  if k:
    ph = []
    for z in k:
      z = re.sub("\D", "", z)
      if z[0] == "1":
        z = z[1:]

      if len(z) != 10:
        pass
      else:
        #print("no: " + z)
        ph.append(phoneLookup(z))
    print("ph: " + str(ph))
    if True in ph:
      search.append('yes')
    else:
      search.append('no')
  else:
    search.append('no')
search
# Out:
# ph: [True]
# ph: []
# ph: [True, True, True, True, True, True]
# ph: [True, True, True, True, True, True, True, True, True]
# ph: []
# ph: [True, True, True, True, True, True, True, True]
# ph: [True, True, True, True, True, True]
# ph: [True, False, True, False, False, True, False]
# ph: [False, False, False, False, False, False]
# ph: [False, True, True, False, True, True]
# ph: [False, False, False, False, True, False, False, False, True, True, True, True, False, True, True, True, True]
# ph: []
# ph: [False, True, False, False, False, False, False, False, False, False]
# ph: [True, True]
# ph: [False, False, False, False, False, False]
# ph: [False, False, False, False, False, False, False, False, False, False, False, False]
# ['no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no']

# %%
df['valid_phone'] = search 
df
# Out:
#     index                                                url  \
# 0       0             https://acariahealth.envolvehealth.com
# 1       0                       https://www.accredo.pharmacy
# 2       0                      https://www.alphascriptrx.com
# 3       0                          https://www.aoncology.com
# 4       0         https://www.cornerstonehealthsolutions.org
# 5       0                       https://www.curanthealth.com
# 6       0      https://www.friendswoodhealthmartpharmacy.com
# 7       0                          https://eaglepharmacy.com
# 8       0                    https://www.express-scripts.com
# 9       0                     https://www.essentiahealth.org
# 10      0                https://www.dfwwellnesspharmacy.com
# 11      0  https://intermountainhealthcare.org/services/p...
# 12      0                           https://www.geniusrx.com
# 13      0                   https://www.orsinihealthcare.com
# 14      0                       https://www.pantherxrare.com
# 15      0                     https://www.mintrxpharmacy.com
# 16      0                           https://www.flcancer.com
# 17      0                  https://www.scriptsrxpharmacy.com
# 18      0                         https://www.senderrarx.com
# 19      0                         https://www.synergenrx.com
# 20      0                              https://mylocalrx.org
# 21      0                            https://www.vascorx.com
# 22      0                          https://www.walgreens.com
#
#                                                  text  \
# 0                                    [\n, \n, \n, \n]
# 1   [\n, \n            Skip to main content\n     ...
# 2   [\n, \n, \n, \n, \n, \n, (650) 412-4530, \n, p...
\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, Locat...      no          no
# 1   [\n, \n            Skip to main content\n     ...     yes          no
# 2   [\n, \n, \n, \n, \n, \n, (650) 412-4530, \n, p...     yes         yes
# 3   [\n, \n    <div class="wpautoterms-update-noti...      no          no
# 4   [\n, Skip to main content\n    ,  , \n, \n, \n...     yes          no
# 5   [\n,  , \n, \n, \n, \n, Join Our Team, \n, \n,...     yes         yes
# 6   [\n, \n, \r\n\t\tSkip to content, \n, \n, \n, ...     yes         yes
# 7   [\n, \n, We are currently experiencing issues ...     yes          no
# 8   [ ,  Skip to main content ,  , Menu,  ,  ,  , ...     yes          no
# 9   [\n, \n,  COVID-19 Update, \n, Masks must stil...      no          no
# 10  [\n, \n, \n, \r\n    Curbside Pick-Up and No-C...     yes         yes
# 11  [\n, \n, \n, \n, \n, Skip to main content, \n,...     yes          no
# 12  [\n,  ,  , \n, \n, \n, \n, Looking to save up ...     yes         yes
# 13  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...     yes         yes
# 14  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...     yes          no
# 15  [\n, \n, \n, \n, \n, \n, Skip to main content,...     yes         yes
# 16  [\n, \n, \n, \n, \n, \r\n    window._monsido =...      no          no
# 17  [\n, \n    var bodyCacheable = true;\n    \n  ...     yes         yes
# 18  [\n, \n, \n, \n, \n, Skip to the main content....     yes          no
# 19  [\n, \n    var bodyCacheable = true;\n    \n  ...     yes         yes
# 20  [\n, \n, \n, \n, \n, \n, \n\t\tSkip to Main Co...      no         yes
# 21  [\n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \n, \...     yes          no
# 22  [\n, \n                Skip to main content\n ...     yes          no

# %% [markdown]
# ## *** TO DO
#
# Need to clean up the image_url column. Some of the urls are not .png/.jpeg files, some don't have a suffix at all, some have more than 1 'https://' within the url, etc. which are preventing the image from showing up.

# %%
df['image_url'][2]
# Out:
# ['https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.comhttps://alphascriptrx.com/wp-content/uploads/2019/08/logo.png',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.comhttps://alphascriptrx.com/wp-content/uploads/2020/08/Alphascript-Specialty-Pharmacy.png',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.comhttps://alphascriptrx.com/wp-content/uploads/2020/08/Alphasccript-Pharmacist-On-Phone.png',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.comhttps://alphascriptrx.com/wp-content/uploads/2019/09/heart-1.png',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.comhttps://alphascriptrx.com/wp-content/uploads/2019/09/folder.png',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.comhttps://alphascriptrx.com/wp-content/uploads/2019/11/Alphascript-Icon-White-1.png',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.comhttps://alphascriptrx.com/wp-content/uploads/2019/11/2019-11-25_URAC-Accreditation-Seal.png',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.comhttps://alphascriptrx.com/wp-content/uploads/2020/09/URAC-Mail-Service-Accredited-Alphascript-198x300.png',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.comhttps://alphascriptrx.com/wp-content/uploads/2020/09/URAC-Mail-Service-Accredited-Alphascript-198x300.png',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.comhttps://alphascriptrx.com/wp-content/uploads/2019/11/2019-11-25_URAC-Accreditation-Seal.png',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.comhttps://alphascriptrx.com/wp-content/uploads/2020/01/Alphascript-ACHC-Accredited.png',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.comhttps://alphascriptrx.com/wp-content/uploads/2020/01/Alphascript-ACHC-Accredited.png',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.comhttps://alphascriptrx.com/wp-content/uploads/2020/01/PCAB.png',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.comhttps://alphascriptrx.com/wp-content/uploads/2020/01/PCAB.png',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.comhttps://alphascriptrx.com/wp-content/uploads/2020/01/PCAB.png',
#  'https://www.alphascriptrx.com...',
#  'https://www.alphascriptrx.comhttps://openbadges.blob.core.windows.net/bakedbadges-us/f279c890-aa1f-43bc-822d-c78c619a148e-2fd08020-00fe-4dbc-8334-dcb2b4e7f941.png']

# %% [markdown]
# ### Convert image_url to actual images/icon
#
# *** Another issue I found is that when you convert the images in the pandas dataframe and use the below function, it converts df into a table and haven't been able to figure out how to get it back to a dataframe. Not sure if there's a way to export this to a .csv but we'll need to look into that too.

# %%
def path_to_image_html(path):
    return '<img src ="' + path + '"width = "60" >'
df2 = df.explode('image_url')
df2 = HTML(df2.to_html(escape = False, formatters = dict(image_url= path_to_image_html)))

# %%
# df2
