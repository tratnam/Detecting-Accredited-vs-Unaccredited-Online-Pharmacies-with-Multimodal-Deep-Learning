# %%
import pandas as pd 
import numpy as np
import os 
import requests
import urllib
import ssl

# %%
acc_df = pd.read_csv('accredited_images.csv')
unacc_df = pd.read_csv('unaccredited_images.csv')

# %%
acc_df.head()
# Out:
#    Unnamed: 0                                         image_urls
# 0           0  https://acariahealth.envolvehealth.com/content...
# 1           1  https://acariahealth.envolvehealth.com/content...
# 2           2  https://acariahealth.envolvehealth.com/content...
# 3           3  https://acariahealth.envolvehealth.com/content...
# 4           4  https://acariahealth.envolvehealth.com/content...

# %%
## removes spaces and other inconsistencies in the unaccredited urls 

unacc_df['image_urls'] = unacc_df['image_urls'].str.replace(' ', '')
unacc_df['image_urls'] = unacc_df['image_urls'].str.replace('.md..', '.md.')

# %%
unacc_df
# Out:
#      Unnamed: 0                                         image_urls
# 0             0  https://static.wixstatic.com/media/3e04e6_80c2...
# 1             1  https://static.wixstatic.com/media/3e04e6_f842...
# 2             2  https://static.wixstatic.com/media/3e04e6_d015...
# 3             3  https://static.wixstatic.com/media/3e04e6_732c...
# 4             4  https://static.wixstatic.com/media/40120c_f196...
# ..          ...                                                ...
# 734         734    https://drugsforhealth.org/images/i_bitcoin.png
# 735         735  https://drugsforhealth.org/themes/theme1/img/b...
# 736         736      https://buyamoxicillinnorx.comAmoxicillin.jpg
# 737         737    https://buyazithromycinnorx.comAzithromycin.jpg
# 738         738  https://buymetronidazolenorx.comMetronidazole.jpg
#
# [739 rows x 2 columns]

# %%
acc_list = acc_df['image_urls'].tolist()
unacc_list = unacc_df['image_urls'].tolist()

# %%
def sort_urls(raw_links_list):
    url_list = []
    bad_urls = []
    for each in raw_links_list:
        try:
            headers = {'user-agent': 'ds6050 (vkb6bn@virginia.edu)'}
            results = requests.get(each, headers=headers, timeout=2.0)
        except requests.exceptions.RequestException as e:
            #print('Bad URL: ' + each)
            bad_urls.append(each)
            continue
        #print(results)
        #print(each) 
        if results.status_code == 200:
            url_list.append(each)
    return url_list, bad_urls

# %%
acc_img_urls, acc_img_bad = sort_urls(acc_list)

# %%
# acc_img_urls

# %%
unacc_img_urls, unacc_img_bad = sort_urls(unacc_list)

# %% [markdown]
# Create directory of folders
#
# ** ONLY RUN ONCE

# %%
try: 
    os.mkdir('images')
    os.chdir('images')
    
    os.mkdir('accredited')
    os.chdir('accredited')

    path = os.getcwd()
    parent = os.path.dirname(path)
    new_path = os.chdir(parent)
    # print(new_path)
    
    os.mkdir('unaccredited')
    print('Directory created')
    
except:
    pass
# Out:
# Directory created

# %%
acc_path = './accredited/'
unacc_path = './unaccredited/'

# %%
os.getcwd()
# Out:
# '/sfs/qumulo/qhome/fdf7gn'

# %%
# make sure path opens the accredited folder, change if needed
os.chdir(acc_path)

# %%
def download_images(images):
    ssl._create_default_https_context = ssl._create_unverified_context # bypasses SSL errors
    icount=1
    for each in images:
        try:
            if each.endswith('.jpg'):
                urllib.request.urlretrieve(each, f'pic_{str(icount)}.jpg')
            icount += 1
            if each.endswith('.png'):
                urllib.request.urlretrieve(each, f'pic_{str(icount)}.png')
            icount += 1
        except urllib.error.HTTPError as he:
           # print(he.code)
            continue
        except urllib.error.SSLCertVerificationError as ue:
           # print(ue.code)
            continue
    return icount

# %% [markdown]
# ** realized the icount is wrong bc it counts every pic whether it downloads or not, not sure how to fix this

# %%
download_images(acc_img_urls)
# Out:
# 814

# %% [markdown]
# should have 394 images in acc folder

# %%
path = os.getcwd()
parent = os.path.dirname(path)
new_path = os.chdir(parent)

# %%
new_path

# %%
os.chdir(unacc_path)

# %%
os.getcwd()
# Out:
# '/sfs/qumulo/qhome/fdf7gn/images/unaccredited'

# %%
download_images(unacc_img_urls)
# Out:
# 842

# %% [markdown]
# should have 406 images in unacc folder

# %%
# !pip install split-folders
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
#   WARNING: The scripts split-folders, split_folders and splitfolders are installed in '/home/fdf7gn/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed split-folders-0.5.1

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
#      |████████████████████████████████| 60.9 MB 14.4 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.14.5; python_version >= "3.7" in /sfs/qumulo/qhome/fdf7gn/.local/lib/python3.8/site-packages (from opencv-python) (1.23.4)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66

# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
import splitfolders

# %%
os.chdir('/sfs/qumulo/qhome/fdf7gn/images/')

# %%
os.getcwd()
# Out:
# '/sfs/qumulo/qhome/fdf7gn/images'

# %%
splitfolders.ratio('/sfs/qumulo/qhome/fdf7gn/images', output="split", seed=123, ratio=(.8, 0.1,0.1))
# Out:
# Copying files: 794 files [00:06, 123.09 files/s]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf

import cv2
import os

import numpy as np

# %%
labels = ['accredited', 'unaccredited']
img_size = 224
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
train = get_data('/sfs/qumulo/qhome/fdf7gn/images/split/train')
val = get_data('/sfs/qumulo/qhome/fdf7gn/images/split/test')
# Out:
# <ipython-input-17-8c9aff821d98>:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(data)

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("accredited")
    else:
        l.append("unaccredited")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /apps/software/standard/compiler/gcc/9.2.0/jupyter_conda/2020.11-py3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1][0])
plt.title(labels[train[0][1]])
# Out:
# Text(0.5, 1.0, 'accredited')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[-1][0])
plt.title(labels[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'unaccredited')

# %%
x_train = []
y_train = []
x_val = []
y_val = []

for feature, label in train:
  x_train.append(feature)
  y_train.append(label)

for feature, label in val:
  x_val.append(feature)
  y_val.append(label)

# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255

x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")

# %%
base_model.trainable = False

# %%
model = tf.keras.Sequential([base_model,
                                 tf.keras.layers.GlobalAveragePooling2D(),
                                 tf.keras.layers.Dropout(0.2),
                                 tf.keras.layers.Dense(18, activation="softmax")                                     
                                ])

# %%
base_learning_rate = 0.0012
model.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

history = model.fit(x_train,y_train,epochs = 50 , validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 20/20 [==============================] - 6s 205ms/step - loss: 0.0635 - accuracy: 0.9779 - val_loss: 0.3338 - val_accuracy: 0.8780
# Epoch 2/50
# 20/20 [==============================] - 3s 163ms/step - loss: 0.0413 - accuracy: 0.9937 - val_loss: 0.3364 - val_accuracy: 0.8659
# Epoch 3/50
# 20/20 [==============================] - 3s 156ms/step - loss: 0.0474 - accuracy: 0.9905 - val_loss: 0.3330 - val_accuracy: 0.8780
# Epoch 4/50
# 20/20 [==============================] - 3s 154ms/step - loss: 0.0474 - accuracy: 0.9921 - val_loss: 0.3674 - val_accuracy: 0.8902
# Epoch 5/50
# 20/20 [==============================] - 3s 155ms/step - loss: 0.0584 - accuracy: 0.9763 - val_loss: 0.3705 - val_accuracy: 0.8780
# Epoch 6/50
# 20/20 [==============================] - 3s 152ms/step - loss: 0.0568 - accuracy: 0.9842 - val_loss: 0.3277 - val_accuracy: 0.8415
# Epoch 7/50
# 20/20 [==============================] - 3s 155ms/step - loss: 0.0536 - accuracy: 0.9874 - val_loss: 0.3377 - val_accuracy: 0.8659
# Epoch 8/50
# 20/20 [==============================] - 3s 156ms/step - loss: 0.0366 - accuracy: 0.9968 - val_loss: 0.3197 - val_accuracy: 0.8659
# Epoch 9/50
# 20/20 [==============================] - 3s 158ms/step - loss: 0.0397 - accuracy: 0.9937 - val_loss: 0.3396 - val_accuracy: 0.8659
# Epoch 10/50
# 20/20 [==============================] - 3s 157ms/step - loss: 0.0378 - accuracy: 0.9953 - val_loss: 0.3237 - val_accuracy: 0.8659
# Epoch 11/50
# 20/20 [==============================] - 3s 157ms/step - loss: 0.0418 - accuracy: 0.9890 - val_loss: 0.3096 - val_accuracy: 0.8537
# Epoch 12/50
# 20/20 [==============================] - 3s 153ms/step - loss: 0.0324 - accuracy: 0.9968 - val_loss: 0.3503 - val_accuracy: 0.8659
# Epoch 13/50
# 20/20 [==============================] - 3s 155ms/step - loss: 0.0392 - accuracy: 0.9905 - val_loss: 0.3381 - val_accuracy: 0.8659
# Epoch 14/50
# 20/20 [==============================] - 3s 155ms/step - loss: 0.0517 - accuracy: 0.9874 - val_loss: 0.3523 - val_accuracy: 0.8659
# Epoch 15/50
# 20/20 [==============================] - 3s 155ms/step - loss: 0.0483 - accuracy: 0.9826 - val_loss: 0.3089 - val_accuracy: 0.8537
# Epoch 16/50
# 20/20 [==============================] - 3s 158ms/step - loss: 0.0459 - accuracy: 0.9842 - val_loss: 0.3551 - val_accuracy: 0.8659
# Epoch 17/50
# 20/20 [==============================] - 3s 154ms/step - loss: 0.0391 - accuracy: 0.9890 - val_loss: 0.4135 - val_accuracy: 0.8659
# Epoch 18/50
# 20/20 [==============================] - 3s 154ms/step - loss: 0.0425 - accuracy: 0.9890 - val_loss: 0.3658 - val_accuracy: 0.8537
# Epoch 19/50
# 20/20 [==============================] - 3s 160ms/step - loss: 0.0471 - accuracy: 0.9874 - val_loss: 0.3583 - val_accuracy: 0.8415
# Epoch 20/50
# 20/20 [==============================] - 3s 157ms/step - loss: 0.0421 - accuracy: 0.9905 - val_loss: 0.3818 - val_accuracy: 0.8659
# Epoch 21/50
# 20/20 [==============================] - 3s 154ms/step - loss: 0.0420 - accuracy: 0.9858 - val_loss: 0.3443 - val_accuracy: 0.8659
# Epoch 22/50
# 20/20 [==============================] - 3s 156ms/step - loss: 0.0371 - accuracy: 0.9921 - val_loss: 0.3871 - val_accuracy: 0.8780
# Epoch 23/50
# 20/20 [==============================] - 3s 157ms/step - loss: 0.0453 - accuracy: 0.9842 - val_loss: 0.3797 - val_accuracy: 0.8659
# Epoch 24/50
# 20/20 [==============================] - 3s 159ms/step - loss: 0.0382 - accuracy: 0.9905 - val_loss: 0.3639 - val_accuracy: 0.8659
# Epoch 25/50
# 20/20 [==============================] - 3s 156ms/step - loss: 0.0316 - accuracy: 0.9968 - val_loss: 0.3618 - val_accuracy: 0.8659
# Epoch 26/50
# 20/20 [==============================] - 3s 159ms/step - loss: 0.0343 - accuracy: 0.9905 - val_loss: 0.3536 - val_accuracy: 0.8415
# Epoch 27/50
# 20/20 [==============================] - 3s 157ms/step - loss: 0.0398 - accuracy: 0.9874 - val_loss: 0.3580 - val_accuracy: 0.8293
# Epoch 28/50
# 20/20 [==============================] - 3s 158ms/step - loss: 0.0275 - accuracy: 0.9984 - val_loss: 0.3931 - val_accuracy: 0.8659
# Epoch 29/50
# 20/20 [==============================] - 3s 158ms/step - loss: 0.0451 - accuracy: 0.9858 - val_loss: 0.3459 - val_accuracy: 0.8415
# Epoch 30/50
# 20/20 [==============================] - 3s 158ms/step - loss: 0.0371 - accuracy: 0.9921 - val_loss: 0.3549 - val_accuracy: 0.8537
# Epoch 31/50
# 20/20 [==============================] - 3s 161ms/step - loss: 0.0308 - accuracy: 0.9953 - val_loss: 0.3994 - val_accuracy: 0.8659
# Epoch 32/50
# 20/20 [==============================] - 3s 157ms/step - loss: 0.0330 - accuracy: 0.9905 - val_loss: 0.3951 - val_accuracy: 0.8780
# Epoch 33/50
# 20/20 [==============================] - 3s 161ms/step - loss: 0.0299 - accuracy: 0.9937 - val_loss: 0.3810 - val_accuracy: 0.8537
# Epoch 34/50
# 20/20 [==============================] - 3s 157ms/step - loss: 0.0317 - accuracy: 0.9953 - val_loss: 0.3662 - val_accuracy: 0.8171
# Epoch 35/50
# 20/20 [==============================] - 3s 155ms/step - loss: 0.0421 - accuracy: 0.9842 - val_loss: 0.3732 - val_accuracy: 0.8537
# Epoch 36/50
# 20/20 [==============================] - 3s 156ms/step - loss: 0.0275 - accuracy: 0.9968 - val_loss: 0.4528 - val_accuracy: 0.8780
# Epoch 37/50
# 20/20 [==============================] - 3s 157ms/step - loss: 0.0369 - accuracy: 0.9890 - val_loss: 0.4022 - val_accuracy: 0.8415
# Epoch 38/50
# 20/20 [==============================] - 3s 157ms/step - loss: 0.0348 - accuracy: 0.9905 - val_loss: 0.3990 - val_accuracy: 0.8293
# Epoch 39/50
# 20/20 [==============================] - 3s 156ms/step - loss: 0.0344 - accuracy: 0.9905 - val_loss: 0.4065 - val_accuracy: 0.8537
# Epoch 40/50
# 20/20 [==============================] - 3s 152ms/step - loss: 0.0238 - accuracy: 0.9984 - val_loss: 0.4568 - val_accuracy: 0.8780
# Epoch 41/50
# 20/20 [==============================] - 3s 154ms/step - loss: 0.0315 - accuracy: 0.9905 - val_loss: 0.3917 - val_accuracy: 0.8415
# Epoch 42/50
# 20/20 [==============================] - 3s 155ms/step - loss: 0.0319 - accuracy: 0.9905 - val_loss: 0.3952 - val_accuracy: 0.8415
# Epoch 43/50
# 20/20 [==============================] - 3s 162ms/step - loss: 0.0312 - accuracy: 0.9953 - val_loss: 0.4194 - val_accuracy: 0.8415
# Epoch 44/50
# 20/20 [==============================] - 3s 162ms/step - loss: 0.0335 - accuracy: 0.9905 - val_loss: 0.4184 - val_accuracy: 0.8537
# Epoch 45/50
# 20/20 [==============================] - 3s 161ms/step - loss: 0.0334 - accuracy: 0.9905 - val_loss: 0.3776 - val_accuracy: 0.8415
# Epoch 46/50
# 20/20 [==============================] - 3s 158ms/step - loss: 0.0453 - accuracy: 0.9826 - val_loss: 0.4093 - val_accuracy: 0.8537
# Epoch 47/50
# 20/20 [==============================] - 3s 152ms/step - loss: 0.0340 - accuracy: 0.9905 - val_loss: 0.3951 - val_accuracy: 0.8415
# Epoch 48/50
# 20/20 [==============================] - 3s 155ms/step - loss: 0.0294 - accuracy: 0.9905 - val_loss: 0.4328 - val_accuracy: 0.8659
# Epoch 49/50
# 20/20 [==============================] - 3s 156ms/step - loss: 0.0249 - accuracy: 0.9968 - val_loss: 0.3890 - val_accuracy: 0.8537
# Epoch 50/50
# 20/20 [==============================] - 3s 153ms/step - loss: 0.0279 - accuracy: 0.9937 - val_loss: 0.5083 - val_accuracy: 0.8780

# %%
model.evaluate(x=x_val, y=y_val)
# Out:
# 3/3 [==============================] - 0s 126ms/step - loss: 0.3046 - accuracy: 0.8780
# [0.3046078681945801, 0.8780487775802612]

# %%
mobilenet_acc = model.evaluate(x=x_val, y=y_val)[1]
# Out:
# 3/3 [==============================] - 0s 108ms/step - loss: 0.3046 - accuracy: 0.8780

# %%
mobilenet_acc
# Out:
# 0.8780487775802612

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(50)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
