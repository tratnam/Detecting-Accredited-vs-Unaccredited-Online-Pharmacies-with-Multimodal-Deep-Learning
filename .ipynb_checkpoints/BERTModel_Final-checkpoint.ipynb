# %% [markdown]
# ## BERT for Pharmacy Website Text Classification
# ### Goal: Train model to determine if online pharmacy is accredited or not.
# #### Dataset:
# - Accredited Online Pharmacies are labeled 0
# - Non-Accredited Online Pharmacies are labeled 1
# - 'Text' column created in this notebook is a combination of body, footer, and header text scraped from each website
# - This is a subset of websites. The final dataset will be larger.

# %% [markdown]
# ### Text Pre-Processing for Feature-Based Training
# - BERT (Bidirectional Encoder Representations from Transformers)
# - BERT makes use of a Transformer, an attention mechanism that learns contextual relations between words (or sub-words) in a text
# - Transformer includes two separate mechanisms — an encoder that reads the text input and a decoder that produces a prediction for the task.
# - Since BERT’s goal is to generate a language model, only the encoder mechanism is necessary
# - the Transformer encoder reads the entire sequence of words at once
#
# - Resources:
#     - https://keras.io/examples/nlp/text_extraction_with_bert/#preprocess-the-data
#     - https://collab.its.virginia.edu/access/lessonbuilder/item/2079372/group/25e8dc9b-3e66-4249-ae38-3a124dead1e4/Module%207:%20Seque_%2010_12%20-%2010_18/7.5%20%20Video%20+%20Qu_%20and%20Attention/M7.5_%20NLP%20with%20Attention,%20Transformers,%20and%20BERT.pdf
#     - https://towardsdatascience.com/multi-label-text-classification-using-bert-and-tensorflow-d2e88d8f488d#98ee
#     - https://curiousily.com/posts/multi-label-text-classification-with-bert-and-pytorch-lightning/
#     - https://www.tensorflow.org/text/tutorials/classify_text_with_bert
#     - https://swatimeena989.medium.com/bert-text-classification-using-keras-903671e0207d
#     - https://towardsdatascience.com/how-to-train-a-bert-model-from-scratch-72cfce554fc6
#     - https://huggingface.co/docs/tokenizers/pipeline

# %% [markdown]
# ![bertmodel.jpg](attachment:371ae26e-6063-4cb6-b68b-0ea720530d26.jpg)
#
# Two-Phase training:
#
# 1.) Pretrain to understand language
#
# 2.) Finetune to learn a specific task

# %% [markdown]
# ### Setup

# %%
#import libraries
import tensorflow as tf
import tensorflow_hub as hub
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import re
import unicodedata
import nltk
from nltk.corpus import stopwords
import keras
from tqdm import tqdm
import pickle
from keras.models import Model
import keras.backend as K
from sklearn.metrics import confusion_matrix,f1_score,classification_report
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint
import itertools
from keras.models import load_model
from sklearn.utils import shuffle
from transformers import *
from transformers import BertTokenizer, TFBertModel, BertConfig
import tensorflow_text as text

from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalMaxPooling2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model


# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ### Load Data

# %%
#import data
pharm_data = pd.read_csv('pharmacy_dataset_reduced.csv')
data = pharm_data.copy()
data.head(2)
len(data)
# Out:
# 72

# %% [markdown]
# ### Preprocess & Clean Data

# %%
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn')

def clean_stopwords_shortwords(w):
    stopwords_list=stopwords.words('english')
    words = w.split() 
    clean_words = [word for word in words if (word not in stopwords_list) and len(word) > 2]
    return " ".join(clean_words) 

def preprocess_sentence(w):
    w = unicode_to_ascii(w.lower().strip())
    w = re.sub(r"([?.!,¿])", r" ", w)
    w = re.sub(r'[" "]+', " ", w)
    w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)
    w=clean_stopwords_shortwords(w)
    w=re.sub(r'@\w+', '',w)
    return w

# %%
#combine columns into new column containing all text
data['text'] = data['Body'].astype(str) + data['Header'].astype(str) + data['Footer'].astype(str)
data.head(2)
# Out:
#                                   Website  \
# 0  https://acariahealth.envolvehealth.com
# 1                        https://alto.com
#
#                                                 Body  \
# 0  Skip to Main Content Home Contact Insights Sea...
# 1  Shop Alto Essentials to add pharmacy products ...
#
#                                               Header  \
# 0  Home Contact Insights Search Search About Over...
# 1  Shop Alto Essentials to add pharmacy products ...
#
#                                               Footer  \
# 0  Locations Referral Forms Careers Disclaimer HI...
# 1  Our Story Careers Drive for Alto For Providers...
#
#                                           Image Urls  Accredited  Zipcode  \
# 0  ['https://acariahealth.envolvehealth.com/conte...           0        0
# 1  ['https://images.prismic.io/alto/176341aa-258d...           0        0
#
#    Valid_phone                                               text
# 0            1  Skip to Main Content Home Contact Insights Sea...
# 1            1  Shop Alto Essentials to add pharmacy products ...

# %%
#rename Accredited as 'label'
data=data.rename(columns = {'Accredited': 'label'}, inplace = False)
data.head(2)
# Out:
#                                   Website  \
# 0  https://acariahealth.envolvehealth.com
# 1                        https://alto.com
#
#                                                 Body  \
# 0  Skip to Main Content Home Contact Insights Sea...
# 1  Shop Alto Essentials to add pharmacy products ...
#
#                                               Header  \
# 0  Home Contact Insights Search Search About Over...
# 1  Shop Alto Essentials to add pharmacy products ...
#
#                                               Footer  \
# 0  Locations Referral Forms Careers Disclaimer HI...
# 1  Our Story Careers Drive for Alto For Providers...
#
#                                           Image Urls  label  Zipcode  \
# 0  ['https://acariahealth.envolvehealth.com/conte...      0        0
# 1  ['https://images.prismic.io/alto/176341aa-258d...      0        0
#
#    Valid_phone                                               text
# 0            1  Skip to Main Content Home Contact Insights Sea...
# 1            1  Shop Alto Essentials to add pharmacy products ...

# %%
#reduce dataset to only the columns we need, 'label' and 'text'
data = data.drop(['Website', 'Body', 'Header', 'Footer', 'Image Urls', 'Zipcode', 'Valid_phone'], axis=1)

# %%
#Sentences contain the entire text data and labels contain all the corresponding labels
data.head(3)
# Out:
#    label                                               text
# 0      0  Skip to Main Content Home Contact Insights Sea...
# 1      0  Shop Alto Essentials to add pharmacy products ...
# 2      0  Loading... Skip to navigation Skip to main con...

# %%
#drop any missing values
data = data.dropna()

# %%
#reset index
data=data.reset_index(drop=True) 
#shuffle data
data = shuffle(data)   
data.head(3)
# Out:
#     label                                               text
# 4       0  Loading... × Close alert Fly with Birdi!  Free...
# 62      1  Log In Register Checkout Languages: Currencies...
# 18      0  Looking to save up to 80% on your medications?...

# %%
#apply the function to clean the text - all lower case, strip spaces and characters 
data['text']=data['text'].map(preprocess_sentence)    
data.head(3)
# Out:
#     label                                               text
# 4       0  loading close alert fly birdi free shipping or...
# 62      1  log register checkout languages currencies dol...
# 18      0  looking save medications find mygeniusrx healt...

# %% [markdown]
# ### Split Data - Training & Testing

# %%
#define the number of unique classes under 'label'
num_classes=len(data.label.unique())
num_classes
# Out:
# 2

# %%
#define y variable
y = tf.keras.utils.to_categorical(data["label"].values, num_classes=num_classes)
#y

# %%
#split data into test and train
x_train, x_test, y_train, y_test = train_test_split(data['text'], y, test_size=0.3)
len(x_train), len(x_test), len(y_train), len(y_test)
# Out:
# (50, 22, 50, 22)

# %% [markdown]
# ### Data Modeling

# %% [markdown]
# #### Load BERT with TensorFlow Hub
# - repository of trained machine learning models
# - use universal-sentence-encoder-cmlm/multilingual-base = universal sentence encoder (100+ languages)
#     - uses conditional masked language model
# - Goal: turn text into high-dim vectors that capture sentence-level semantics
#     - get embeddings from input text with preprocessor and encoder

# %%
#load bert with tensorflow hub
preprocessor = hub.KerasLayer("https://tfhub.dev/google/universal-sentence-encoder-cmlm/multilingual-preprocess/2")
encoder = hub.KerasLayer("https://tfhub.dev/google/universal-sentence-encoder-cmlm/multilingual-base/1")

#function to get word embeddings
def get_embeddings(sentences):
  '''return BERT-like embeddings of input text
  Args:
    - sentences: list of strings
  Output:
    - BERT-like embeddings: tf.Tensor of shape=(len(sentences), 768)
  '''
  preprocessed_text = preprocessor(sentences)
  return encoder(preprocessed_text)['pooled_output']

#test function
#get_embeddings([
   # "This is a test para ver el futuro of the model."])
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.

# %%
## Note: an option in the future is to observe semantic textual similarities

# %% [markdown]
# ### Create & Train Classification Model
# - Observe different metrics during training: Precision, Recall, F1 Score

# %%
#resource: https://towardsdatascience.com/multi-label-text-classification-using-bert-and-tensorflow-d2e88d8f488d#98ee
from keras import backend as K

#functions to find recall
def balanced_recall(y_true, y_pred):
    """This function calculates the balanced recall metric
    recall = TP / (TP + FN)
    """
    recall_by_class = 0
    # iterate over each predicted class to get class-specific metric
    for i in range(y_pred.shape[1]):
        y_pred_class = y_pred[:, i]
        y_true_class = y_true[:, i]
        true_positives = K.sum(K.round(K.clip(y_true_class * y_pred_class, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true_class, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        recall_by_class = recall_by_class + recall
    return recall_by_class / y_pred.shape[1]

#functions to find precision
def balanced_precision(y_true, y_pred):
    """This function calculates the balanced precision metric
    precision = TP / (TP + FP)
    """
    precision_by_class = 0
    # iterate over each predicted class to get class-specific metric
    for i in range(y_pred.shape[1]):
        y_pred_class = y_pred[:, i]
        y_true_class = y_true[:, i]
        true_positives = K.sum(K.round(K.clip(y_true_class * y_pred_class, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred_class, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        precision_by_class = precision_by_class + precision
    # return average balanced metric for each class
    return precision_by_class / y_pred.shape[1]

#functions to find f1 score
def balanced_f1_score(y_true, y_pred):
    """This function calculates the F1 score metric"""
    precision = balanced_precision(y_true, y_pred)
    recall = balanced_recall(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# %% [markdown]
# #### Define Model
# - preporcessor & encoder layers
# - dropout & dense layer with softmax activation function
# - output space dimension = # of classes

# %%
#define model
i = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
x = preprocessor(i)
x = encoder(x)
x = tf.keras.layers.Dropout(0.2, name="dropout")(x['pooled_output'])
x = tf.keras.layers.Dense(num_classes, activation='softmax', name="output")(x)

bert_model = tf.keras.Model(i, x)

# %%
#model.summary()

# %%
# saving and loading the .h5 model
# save model
#model.save('Model.h5')
#print('Model Saved!')

# %% [markdown]
# #### Compile & Fit Model

# %%
#define number of epochs
n_epochs = 50

METRICS = [
      tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
      tf.keras.metrics.TrueNegatives(),
      tf.keras.metrics.FalsePositives(),
      tf.keras.metrics.AUC(),
      balanced_recall,
      balanced_precision,
      balanced_f1_score
]

#EarlyStopping callback to monitor validation loss
#if metric doesn't improve for at least 3 epochs (patience = 3)
    #training is interrupted and weights from epoch where the validation loss 
    #showed the best value (i.e. lowest) are restored (restore_best_weights = True)
earlystop_callback = tf.keras.callbacks.EarlyStopping(monitor = "val_loss", 
                                                      patience = 3,
                                                      restore_best_weights = True)
#compile model
bert_model.compile(optimizer = "adam",
              loss = "categorical_crossentropy",
              metrics = METRICS)
#fit model
bert_model = bert_model.fit(x_train, 
                      y_train, 
                      epochs = n_epochs,
                      validation_data = (x_test, y_test),
                      callbacks = [earlystop_callback], verbose=1)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 12s 6s/step - loss: 0.7839 - accuracy: 0.4800 - true_negatives_4: 24.0000 - false_positives: 26.0000 - balanced_recall: 0.4656 - balanced_precision: 0.4207 - balanced_f1_score: 0.4419 - val_loss: 0.6309 - val_accuracy: 0.7273 - val_true_negatives_4: 16.0000 - val_false_positives: 6.0000 - val_balanced_recall: 0.6562 - val_balanced_precision: 0.6562 - val_balanced_f1_score: 0.6562
# Epoch 2/50
# 2/2 [==============================] - 6s 4s/step - loss: 0.7068 - accuracy: 0.5400 - true_negatives_4: 27.0000 - false_positives: 23.0000 - balanced_recall: 0.5562 - balanced_precision: 0.5556 - balanced_f1_score: 0.5559 - val_loss: 0.6460 - val_accuracy: 0.6364 - val_true_negatives_4: 14.0000 - val_false_positives: 8.0000 - val_balanced_recall: 0.5938 - val_balanced_precision: 0.5804 - val_balanced_f1_score: 0.5870
# Epoch 3/50
# 2/2 [==============================] - 6s 4s/step - loss: 0.6369 - accuracy: 0.5800 - true_negatives_4: 29.0000 - false_positives: 21.0000 - balanced_recall: 0.5906 - balanced_precision: 0.6027 - balanced_f1_score: 0.5966 - val_loss: 0.6424 - val_accuracy: 0.6818 - val_true_negatives_4: 15.0000 - val_false_positives: 7.0000 - val_balanced_recall: 0.7292 - val_balanced_precision: 0.6818 - val_balanced_f1_score: 0.7047
# Epoch 4/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.6267 - accuracy: 0.6000 - true_negatives_4: 30.0000 - false_positives: 20.0000 - balanced_recall: 0.6090 - balanced_precision: 0.6090 - balanced_f1_score: 0.6090 - val_loss: 0.6175 - val_accuracy: 0.7273 - val_true_negatives_4: 16.0000 - val_false_positives: 6.0000 - val_balanced_recall: 0.7604 - val_balanced_precision: 0.7083 - val_balanced_f1_score: 0.7335
# Epoch 5/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.6273 - accuracy: 0.6400 - true_negatives_4: 32.0000 - false_positives: 18.0000 - balanced_recall: 0.7007 - balanced_precision: 0.7007 - balanced_f1_score: 0.7007 - val_loss: 0.5842 - val_accuracy: 0.7273 - val_true_negatives_4: 16.0000 - val_false_positives: 6.0000 - val_balanced_recall: 0.7604 - val_balanced_precision: 0.7083 - val_balanced_f1_score: 0.7335
# Epoch 6/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.5298 - accuracy: 0.8200 - true_negatives_4: 41.0000 - false_positives: 9.0000 - balanced_recall: 0.8225 - balanced_precision: 0.8246 - balanced_f1_score: 0.8236 - val_loss: 0.5536 - val_accuracy: 0.7727 - val_true_negatives_4: 17.0000 - val_false_positives: 5.0000 - val_balanced_recall: 0.7917 - val_balanced_precision: 0.7393 - val_balanced_f1_score: 0.7646
# Epoch 7/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.4866 - accuracy: 0.8600 - true_negatives_4: 43.0000 - false_positives: 7.0000 - balanced_recall: 0.8827 - balanced_precision: 0.8663 - balanced_f1_score: 0.8744 - val_loss: 0.5235 - val_accuracy: 0.7727 - val_true_negatives_4: 17.0000 - val_false_positives: 5.0000 - val_balanced_recall: 0.7917 - val_balanced_precision: 0.7393 - val_balanced_f1_score: 0.7646
# Epoch 8/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.4810 - accuracy: 0.8600 - true_negatives_4: 43.0000 - false_positives: 7.0000 - balanced_recall: 0.8621 - balanced_precision: 0.8642 - balanced_f1_score: 0.8632 - val_loss: 0.5002 - val_accuracy: 0.8182 - val_true_negatives_4: 18.0000 - val_false_positives: 4.0000 - val_balanced_recall: 0.8229 - val_balanced_precision: 0.7768 - val_balanced_f1_score: 0.7992
# Epoch 9/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.4816 - accuracy: 0.8800 - true_negatives_4: 44.0000 - false_positives: 6.0000 - balanced_recall: 0.8837 - balanced_precision: 0.8938 - balanced_f1_score: 0.8887 - val_loss: 0.4745 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 10/50
# 2/2 [==============================] - 8s 5s/step - loss: 0.4247 - accuracy: 0.9000 - true_negatives_4: 45.0000 - false_positives: 5.0000 - balanced_recall: 0.8719 - balanced_precision: 0.8623 - balanced_f1_score: 0.8670 - val_loss: 0.4547 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 11/50
# 2/2 [==============================] - 8s 5s/step - loss: 0.4137 - accuracy: 0.9200 - true_negatives_4: 46.0000 - false_positives: 4.0000 - balanced_recall: 0.9254 - balanced_precision: 0.9267 - balanced_f1_score: 0.9260 - val_loss: 0.4455 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 12/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.4115 - accuracy: 0.8600 - true_negatives_4: 43.0000 - false_positives: 7.0000 - balanced_recall: 0.8601 - balanced_precision: 0.8478 - balanced_f1_score: 0.8539 - val_loss: 0.4386 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 13/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.3623 - accuracy: 0.9400 - true_negatives_4: 47.0000 - false_positives: 3.0000 - balanced_recall: 0.9474 - balanced_precision: 0.9325 - balanced_f1_score: 0.9399 - val_loss: 0.4332 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 14/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.3166 - accuracy: 0.9400 - true_negatives_4: 47.0000 - false_positives: 3.0000 - balanced_recall: 0.9410 - balanced_precision: 0.9460 - balanced_f1_score: 0.9435 - val_loss: 0.4196 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 15/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.3319 - accuracy: 0.9600 - true_negatives_4: 48.0000 - false_positives: 2.0000 - balanced_recall: 0.9594 - balanced_precision: 0.9575 - balanced_f1_score: 0.9584 - val_loss: 0.4071 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 16/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.3155 - accuracy: 0.9200 - true_negatives_4: 46.0000 - false_positives: 4.0000 - balanced_recall: 0.9191 - balanced_precision: 0.9317 - balanced_f1_score: 0.9254 - val_loss: 0.3914 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 17/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.3027 - accuracy: 0.9400 - true_negatives_4: 47.0000 - false_positives: 3.0000 - balanced_recall: 0.9428 - balanced_precision: 0.9456 - balanced_f1_score: 0.9442 - val_loss: 0.3764 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 18/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2771 - accuracy: 0.9400 - true_negatives_4: 47.0000 - false_positives: 3.0000 - balanced_recall: 0.9375 - balanced_precision: 0.9495 - balanced_f1_score: 0.9435 - val_loss: 0.3628 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 19/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2688 - accuracy: 0.9600 - true_negatives_4: 48.0000 - false_positives: 2.0000 - balanced_recall: 0.9686 - balanced_precision: 0.9686 - balanced_f1_score: 0.9686 - val_loss: 0.3518 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 20/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2625 - accuracy: 0.9800 - true_negatives_4: 49.0000 - false_positives: 1.0000 - balanced_recall: 0.9688 - balanced_precision: 0.9773 - balanced_f1_score: 0.9730 - val_loss: 0.3431 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 21/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2493 - accuracy: 0.9800 - true_negatives_4: 49.0000 - false_positives: 1.0000 - balanced_recall: 0.9861 - balanced_precision: 0.9833 - balanced_f1_score: 0.9847 - val_loss: 0.3365 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 22/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2353 - accuracy: 0.9600 - true_negatives_4: 48.0000 - false_positives: 2.0000 - balanced_recall: 0.9444 - balanced_precision: 0.9545 - balanced_f1_score: 0.9494 - val_loss: 0.3302 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 23/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2358 - accuracy: 0.9800 - true_negatives_4: 49.0000 - false_positives: 1.0000 - balanced_recall: 0.9833 - balanced_precision: 0.9861 - balanced_f1_score: 0.9847 - val_loss: 0.3254 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 24/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2244 - accuracy: 0.9400 - true_negatives_4: 47.0000 - false_positives: 3.0000 - balanced_recall: 0.9520 - balanced_precision: 0.9544 - balanced_f1_score: 0.9532 - val_loss: 0.3200 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 25/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2204 - accuracy: 0.9600 - true_negatives_4: 48.0000 - false_positives: 2.0000 - balanced_recall: 0.9686 - balanced_precision: 0.9686 - balanced_f1_score: 0.9686 - val_loss: 0.3161 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 26/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2219 - accuracy: 0.9600 - true_negatives_4: 48.0000 - false_positives: 2.0000 - balanced_recall: 0.9667 - balanced_precision: 0.9737 - balanced_f1_score: 0.9701 - val_loss: 0.3122 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 27/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2246 - accuracy: 0.9200 - true_negatives_4: 46.0000 - false_positives: 4.0000 - balanced_recall: 0.9312 - balanced_precision: 0.9219 - balanced_f1_score: 0.9265 - val_loss: 0.3067 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 28/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1959 - accuracy: 0.9800 - true_negatives_4: 49.0000 - false_positives: 1.0000 - balanced_recall: 0.9861 - balanced_precision: 0.9833 - balanced_f1_score: 0.9847 - val_loss: 0.2996 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 29/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1946 - accuracy: 1.0000 - true_negatives_4: 50.0000 - false_positives: 0.0000e+00 - balanced_recall: 1.0000 - balanced_precision: 1.0000 - balanced_f1_score: 1.0000 - val_loss: 0.2913 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 30/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1937 - accuracy: 0.9600 - true_negatives_4: 48.0000 - false_positives: 2.0000 - balanced_recall: 0.9556 - balanced_precision: 0.9611 - balanced_f1_score: 0.9583 - val_loss: 0.2845 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 31/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1741 - accuracy: 0.9600 - true_negatives_4: 48.0000 - false_positives: 2.0000 - balanced_recall: 0.9375 - balanced_precision: 0.9583 - balanced_f1_score: 0.9477 - val_loss: 0.2784 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 32/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1758 - accuracy: 0.9800 - true_negatives_4: 49.0000 - false_positives: 1.0000 - balanced_recall: 0.9853 - balanced_precision: 0.9844 - balanced_f1_score: 0.9848 - val_loss: 0.2741 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 33/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1630 - accuracy: 1.0000 - true_negatives_4: 50.0000 - false_positives: 0.0000e+00 - balanced_recall: 1.0000 - balanced_precision: 1.0000 - balanced_f1_score: 1.0000 - val_loss: 0.2691 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 34/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1559 - accuracy: 0.9800 - true_negatives_4: 49.0000 - false_positives: 1.0000 - balanced_recall: 0.9844 - balanced_precision: 0.9853 - balanced_f1_score: 0.9848 - val_loss: 0.2634 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 35/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1657 - accuracy: 1.0000 - true_negatives_4: 50.0000 - false_positives: 0.0000e+00 - balanced_recall: 1.0000 - balanced_precision: 1.0000 - balanced_f1_score: 1.0000 - val_loss: 0.2580 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 36/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1506 - accuracy: 0.9800 - true_negatives_4: 49.0000 - false_positives: 1.0000 - balanced_recall: 0.9844 - balanced_precision: 0.9853 - balanced_f1_score: 0.9848 - val_loss: 0.2537 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 37/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1559 - accuracy: 0.9800 - true_negatives_4: 49.0000 - false_positives: 1.0000 - balanced_recall: 0.9833 - balanced_precision: 0.9861 - balanced_f1_score: 0.9847 - val_loss: 0.2502 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 38/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1427 - accuracy: 1.0000 - true_negatives_4: 50.0000 - false_positives: 0.0000e+00 - balanced_recall: 1.0000 - balanced_precision: 1.0000 - balanced_f1_score: 1.0000 - val_loss: 0.2473 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 39/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1529 - accuracy: 0.9800 - true_negatives_4: 49.0000 - false_positives: 1.0000 - balanced_recall: 0.9844 - balanced_precision: 0.9853 - balanced_f1_score: 0.9848 - val_loss: 0.2454 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 40/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1331 - accuracy: 1.0000 - true_negatives_4: 50.0000 - false_positives: 0.0000e+00 - balanced_recall: 1.0000 - balanced_precision: 1.0000 - balanced_f1_score: 1.0000 - val_loss: 0.2438 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 41/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1363 - accuracy: 1.0000 - true_negatives_4: 50.0000 - false_positives: 0.0000e+00 - balanced_recall: 1.0000 - balanced_precision: 1.0000 - balanced_f1_score: 1.0000 - val_loss: 0.2416 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 42/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1313 - accuracy: 1.0000 - true_negatives_4: 50.0000 - false_positives: 0.0000e+00 - balanced_recall: 1.0000 - balanced_precision: 1.0000 - balanced_f1_score: 1.0000 - val_loss: 0.2389 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 43/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1358 - accuracy: 0.9800 - true_negatives_4: 49.0000 - false_positives: 1.0000 - balanced_recall: 0.9808 - balanced_precision: 0.9875 - balanced_f1_score: 0.9841 - val_loss: 0.2360 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 44/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1183 - accuracy: 1.0000 - true_negatives_4: 50.0000 - false_positives: 0.0000e+00 - balanced_recall: 1.0000 - balanced_precision: 1.0000 - balanced_f1_score: 1.0000 - val_loss: 0.2344 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 45/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1193 - accuracy: 1.0000 - true_negatives_4: 50.0000 - false_positives: 0.0000e+00 - balanced_recall: 1.0000 - balanced_precision: 1.0000 - balanced_f1_score: 1.0000 - val_loss: 0.2316 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 46/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1412 - accuracy: 1.0000 - true_negatives_4: 50.0000 - false_positives: 0.0000e+00 - balanced_recall: 1.0000 - balanced_precision: 1.0000 - balanced_f1_score: 1.0000 - val_loss: 0.2295 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 47/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1190 - accuracy: 1.0000 - true_negatives_4: 50.0000 - false_positives: 0.0000e+00 - balanced_recall: 1.0000 - balanced_precision: 1.0000 - balanced_f1_score: 1.0000 - val_loss: 0.2268 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 48/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1094 - accuracy: 1.0000 - true_negatives_4: 50.0000 - false_positives: 0.0000e+00 - balanced_recall: 1.0000 - balanced_precision: 1.0000 - balanced_f1_score: 1.0000 - val_loss: 0.2254 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 49/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1247 - accuracy: 0.9800 - true_negatives_4: 49.0000 - false_positives: 1.0000 - balanced_recall: 0.9688 - balanced_precision: 0.9773 - balanced_f1_score: 0.9730 - val_loss: 0.2239 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429
# Epoch 50/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1129 - accuracy: 0.9800 - true_negatives_4: 49.0000 - false_positives: 1.0000 - balanced_recall: 0.9773 - balanced_precision: 0.9688 - balanced_f1_score: 0.9730 - val_loss: 0.2217 - val_accuracy: 0.9545 - val_true_negatives_4: 21.0000 - val_false_positives: 1.0000 - val_balanced_recall: 0.9167 - val_balanced_precision: 0.9706 - val_balanced_f1_score: 0.9429

# %%
#bert_model.history['accuracy']

# %% [markdown]
# ### Plot Results

# %%
x = list(range(1, n_epochs+1))
metric_list = list(bert_model.history.keys())
num_metrics = int(len(metric_list)/2)

fig, ax = plt.subplots(nrows=1, ncols=num_metrics, figsize=(30, 5))

for i in range(0, num_metrics):
  ax[i].plot(x, bert_model.history[metric_list[i]], marker="o", label=metric_list[i].replace("_", " "))
  ax[i].plot(x, bert_model.history[metric_list[i+num_metrics]], marker="o", label=metric_list[i+num_metrics].replace("_", " "))
  ax[i].set_xlabel("epochs",fontsize=14)
  ax[i].set_title(metric_list[i].replace("_", " "),fontsize=20)
  ax[i].legend(loc="lower left")

# %%
metric_list
# Out:
# ['loss',
#  'accuracy',
#  'true_negatives_4',
#  'false_positives',
#  'balanced_recall',
#  'balanced_precision',
#  'balanced_f1_score',
#  'val_loss',
#  'val_accuracy',
#  'val_true_negatives_4',
#  'val_false_positives',
#  'val_balanced_recall',
#  'val_balanced_precision',
#  'val_balanced_f1_score']
