# %% [markdown]
# The first piece takes the accredited pharmacy set and creates a data frame with the name and urls of each site.  Three rows were removed-- two were missing urls, while one was causing issues to the loop.  'gg' is the data frame, while 'data' is a list of the urls. After that there are numerous scraper functions I have been trying to write to grab different pieces of the content.  'datatest' is a smaller list I have been using to test things out prior to running the entire list. Along those same lines, 'd1', 'd2','d3', and 'd4' are all sublists of the larger list of urls.  I keep running into 403 errors and issues with the loop so I have begun splitting everything up to see if I can identify where things go wrong. I have noticed 403 errors throughout all of the subsets.  These are identified by the BINGO lines, however, there is something about the 'd2' and 'd4' subsets that keep getting the function stuck.  pdb can be used to determine where the issue lies, or the subsets may need further split until the culprit is found.  The data frames themselves are an issue also.  The data frames contain multiples of the same lines.  This has caused multiples of a lot of rows. I am not sure how to fix this within the loop, but I think grouping by the index of the dataframe might be an easier fix for the problem anyway.   I still need to apply a lot of these same ideas to the list of bad websites.

# %%
import pandas as pd

from urllib.request import urlopen
from bs4 import BeautifulSoup
import pdb
from urllib.request import urlopen, Request
import requests


df = pd.read_csv('Accredited Digital Pharmacies _ National Association of Boards of Pharmacy.csv')

df['url'] = df['Website'].str.strip()

df['u2'] = df['url'].str.replace(r'\n\n\n\tif', ' ')


df['urls'] = df['u2'].str.split(' ').str[0]

df['Name'] = df['BusinessName_PharmacyName'].str.split('\n\t\t').str[1]

gg = df[['Name','urls']]

gg['urls'] = gg['urls'].str.strip('https://')

gg = gg.iloc[: , 0:]

gg.to_csv('good_guys.csv',index = False)

gg = gg.drop([2, 46, 78]) ##### I DROPPED TWO ROWS THAT WERE MISSING URLs!!!!

gg.tail(10)

data = gg['urls'].tolist()
# Out:
# <ipython-input-1-0a024e26df20>:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['u2'] = df['url'].str.replace(r'\n\n\n\tif', ' ')
# <ipython-input-1-0a024e26df20>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gg['urls'] = gg['urls'].str.strip('https://')

# %%
gg
# Out:
#                          Name                              urls
# 0           AcariaHealth, Inc    acariahealth.envolvehealth.com
# 1   Accredo Health Group, Inc              www.accredo.pharmacy
# 3           Alphascript, Inc.             www.alphascriptrx.com
# 4              Alto Pharmacy                           alto.com
# 5    Amber Specialty Pharmacy             www.amberpharmacy.com
# ..                        ...                               ...
# 82              Wal-Mart, Inc  www.walmart.com/cp/pharmacy/5431
# 83                Walgreen Co                 www.walgreens.com
# 84          Weis Markets, Inc               www.weismarkets.com
# 85            WellDyneRx, LLC                www.welldynerx.com
# 86      Your Rx Pharmacy, Inc            www.yourrxpharmacy.com
#
# [84 rows x 2 columns]

# %%
data
# Out:
# ['acariahealth.envolvehealth.com',
#  'www.accredo.pharmacy',
#  'www.alphascriptrx.com',
#  'alto.com',
#  'www.amberpharmacy.com',
#  'www.medvantxrx.com',
#  'www.aoncology.com',
#  'www.citizenpharmacy.com',
#  'www.bioplusrx.com',
#  'www.birdirx.com',
#  'www.cornerstonehealthsolutions.org',
#  'www.cfspharmacy.pharmacy',
#  'www.caremark.com',
#  'www.carepointrx.com',
#  'redrockhome.pharmacy',
#  'www.centerwellpharmacy.com',
#  'www.carolinacarerx.org',
#  'www.costco.com',
#  'www.curanthealth.com',
#  'www.ccsmed.com',
#  'www.divvydose.com',
#  'www.friendswoodhealthmartpharmacy.com',
#  'eaglepharmacy.com',
#  'envisionpharmacies.com',
#  'www.express-scripts.com',
#  'www.essentiahealth.org',
#  'www.ecspecialtyrx.com',
#  'rosh.pharmacy',
#  'gentryhealthservices.com',
#  'www.dfwwellnesspharmacy.com',
#  'ameripharma.u',
#  'www.harristeeter.com',
#  'www.hometownpharmacy.com',
#  'www.healthwarehouse.com',
#  'www.hy-vee.com',
#  'www.hvrxsolutions.com',
# ...

# %%
datatest = ['acariahealth.envolvehealth.com']

# %%
#####################################################################################

# %%
data1 = ['acariahealth.envolvehealth.com',
 'www.accredo.pharmacy',
 'www.alphascriptrx.com',
 'alto.com',
 'www.amberpharmacy.com',
 'www.medvantxrx.com',
 'www.aoncology.com',
 'www.citizenpharmacy.com',
 'www.bioplusrx.com',
 'www.birdirx.com',
 'www.cornerstonehealthsolutions.org',
 'www.cfspharmacy.pharmacy',
 'www.caremark.com',
 'www.carepointrx.com',
 'redrockhome.pharmacy',
 'www.centerwellpharmacy.com',
 'www.carolinacarerx.org']

# %%
data2 = ['www.costco.com',
 'www.curanthealth.com',
 'www.ccsmed.com',
 'www.divvydose.com',
 'www.friendswoodhealthmartpharmacy.com',
 'eaglepharmacy.com',
 'envisionpharmacies.com',
 'www.express-scripts.com',
 'www.essentiahealth.org',
 'www.ecspecialtyrx.com',
 'rosh.pharmacy',
 'gentryhealthservices.com',
 'www.dfwwellnesspharmacy.com',
 'ameripharma.u',
 'www.harristeeter.com',
 'www.hometownpharmacy.com',
 'www.healthwarehouse.com',
 'www.hy-vee.com',
 'www.hvrxsolutions.com',
 'intermountainhealthcare.org/services/pharmacy',
 'www.iuhealth.org/patients/pharmacie',
 'www.icsrx.com']

# %%
data3 = ['www.memorial.pharmacy',
 'www.kmart.com',
 'www.magellanrx.pharmacy',
 'www.medimpact.com',
 'www.meijer.com',
 'www.geniusrx.com',
 'www.thepillclub.com',
 'www.noblehealthservices.com',
 'www.northcoastmed.com',
 'www.onco360.com',
 'www.optumrx.com',
 'www.orsinihealthcare.com',
 'www.pantherxrare.com',
 'www.rosemontspecialtyrx.com',
 'www.mintrxpharmacy.com',
 'www.amazon.com',
 'ruepill.pharmacy',
 'www.powerhousepharmacy.com',
 'www.ridgeway.pharmacy',
 'www.blueskyspecialtypharmacy.com',
 'www.rxoutreach.org',
 'www.flcancer.com',
 'www.stpeterscommunitypharmacy.com',
 'www.schrafts2.com',
 'www.scriptsrxpharmacy.com',
 'www.senderrarx.com',
 'medhope.pharmacy',
 'www.solerarx.com',
 'www.sortpak.com',
 'www.smrtrx.ne']

# %%
data4 = ['www.synergenrx.com',
 'www.bakersplus.com',
 'metrohealth.pharmacy',
 'mylocalrx.org',
 'www.hopesp.com',
 'www.medicorx.com',
 'aging.depotdrug.com',
 'www.usmed-rx.com',
 'www.vascorx.com',
 'rescriptions.wakehealth.edu',
 'www.walmart.com/cp/pharmacy/5431',
 'www.walgreens.com',
 'www.weismarkets.com',
 'www.welldynerx.com',
 'www.yourrxpharmacy.com']

# %%
######## Body Scraper

# %%
h = 'https://'
d1 = [h+i for i in data1]

bods1= []

def bodyscraper(link):
    try:
        html = urlopen(link)
        headers = {'user-agent': 'Mozilla/5.0'}
        page = requests.get(link,headers)
        soup = BeautifulSoup(page.content,'html.parser')
        body = soup.find_all('body')
    
        for b in body:
            bods1.append(b)
    except:
        bods1.append("BINGO: " + link)
        pass
    
    return(bods1)

body1 = pd.DataFrame()

for i in d1:
    dictObj =bodyscraper(i)
    body1 = body1.append(dictObj)

body1
# Out:
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py:309: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])
#                                                    0   \
# 0                                                  \n
# 0   [\n,  Google Tag Manager (noscript) , \n, [\n,...
# 1   [\n, [\n            Skip to main content\n    ...
# 0   [\n,  Google Tag Manager (noscript) , \n, [\n,...
# 1   [\n, [\n            Skip to main content\n    ...
# ..                                                ...
# 12  [\n, [\n   var a_screen_width = screen.width;\...
# 13                 BINGO: https://www.carepointrx.com
# 14                BINGO: https://redrockhome.pharmacy
# ...

# %%
h = 'https://'
d2 = [h+i for i in data2]

bods2= []

def bodyscraper(link):
    try:
        html = urlopen(link)
        headers = {'user-agent': 'Mozilla/5.0'}
        page = requests.get(link,headers)
        soup = BeautifulSoup(page.content,'html.parser')
        body = soup.find_all('body')
    
        for b in body:
            bods2.append(b)
    except:
        bods2.append("BINGO: " + link)
        pass
    
    return(bods2)

body2 = pd.DataFrame()
for r in d2:
    dictObj =bodyscraper(r)
    body2 = body2.append(dictObj)

body2

# %%
h = 'https://'
d3 = [h+i for i in data3]

bods3= []

def bodyscraper(link):
    try:
        html = urlopen(link)
        headers = {'user-agent': 'Mozilla/5.0'}
        page = requests.get(link,headers)
        soup = BeautifulSoup(page.content,'html.parser')
        body = soup.find_all('body')
    
        for b in body:
            bods3.append(b)
    except:
        bods3.append("BINGO: " + link)
        pass
    
    return(bods3)

body3 = pd.DataFrame()
for i in d3:
    dictObj =bodyscraper(i)
    body3 = body3.append(dictObj)

body3

# %%
h = 'https://'
d4 = [h+i for i in data4]

bods4= []

def bodyscraper(link):
    try:
        html = urlopen(link)
        headers = {'user-agent': 'Mozilla/5.0'}
        page = requests.get(link,headers)
        soup = BeautifulSoup(page.content,'html.parser')
        body = soup.find_all('body')
    
        for b in body:
            bods4.append(b)
    except:
        bods4.append("BINGO: " + link)
        pass
    
    return(bods4)

body4 = pd.DataFrame()
for i in d4:
    dictObj =bodyscraper(i)
    body4 = body4.append(dictObj)

body4
# Out:
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py:309: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])

# %%
########################################

# %%
###### This is where I was trying to gather images, more specifically, this code is me trying to
###### scoop up that accredited certification stamp.

# %%
URL = 'https://www.carolinacarerx.org/'

page = requests.get(URL)

soup = BeautifulSoup(page.content,'html.parser')

images = soup.find_all('a')

images

# %%
#### This scraper only works for 'a' tag

# %%
def logoscraper(link):
    URL = 'https://www.carolinacarerx.org/'

    page = requests.get(URL)

    soup = BeautifulSoup(page.content,'html.parser')

    images = soup.find_all('a')

    return(images)

# %%
body1.head(10)
# Out:
#                                                   0   \
# 0                                                 \n
# 0  [\n,  Google Tag Manager (noscript) , \n, [\n,...
# 1  [\n, [\n            Skip to main content\n    ...
# 0  [\n,  Google Tag Manager (noscript) , \n, [\n,...
# 1  [\n, [\n            Skip to main content\n    ...
# 2  [\n, [[<filter id="wp-duotone-dark-grayscale">...
# 0  [\n,  Google Tag Manager (noscript) , \n, [\n,...
# 1  [\n, [\n            Skip to main content\n    ...
# 2  [\n, [[<filter id="wp-duotone-dark-grayscale">...
# 3  [[[<div id="layout-wrapper"><header><div class...
#
#                                 1    2         3    4    5   \
# 0   Google Tag Manager (noscript)    \n  [\n, []]   \n   \n
# 0                              NaN  NaN       NaN  NaN  NaN
# 1                              NaN  NaN       NaN  NaN  NaN
# 0                              NaN  NaN       NaN  NaN  NaN
# 1                              NaN  NaN       NaN  NaN  NaN
# ...

# %%
####### The rest of this is a lot of scratch work trying to piece together and form different scraper functions. 
####### I am not sure how useful it will be but figured it is better to hold on to just in case.

# %%
h = 'https://'
d1 = [h+i for i in data1]

bods= []

def bodyscraper(link):
    try:
        html = urlopen(link)
        headers = {'user-agent': 'Mozilla/5.0'}
        page = requests.get(link,headers)
        soup = BeautifulSoup(page.content,'html.parser')
        body = soup.find_all('body')
    
        for b in body:
            bods.append(b)
    except:
        bods.append("BINGO: " + link)
        pass
    
    return(bods)

bodies = pd.DataFrame()
for i in d:
    dictObj =bodyscraper(i)
    bodies = bodies.append(dictObj)

bodies

# %%
h = 'https://'
d2 = [h + i for i in datatest]


titles=[]
def scraper(link):
    try:
        htmld = urlopen(link)
        headers = {'user-agent': 'ds6050 (vzw6yk@virginia.edu)'}
        r = requests.get(link, headers=headers)
        soup = BeautifulSoup(htmld,'html.parser')
        body = soup.find_all('body')
        for tag in body:
            titles.append(tag.text.strip())
    except:
        titles.append("This one is a 403 error ---- " + link)
        pass
    return (titles)
mainDataFrame = pd.DataFrame()
for i in d2:
    dictObj =scraper(i)
    mainDataFrame = mainDataFrame.append(dictObj)

# %%
mainDataFrame

# %%
h = 'https://'
d2 = [h + i for i in datatest2]
titles=[]
def scraper(link):
    try:
        htmld = urlopen(link)
        headers = {'user-agent': 'Mozilla/5.0'}
        r = Request(link, headers=headers)
        soup = BeautifulSoup(htmld,'html.parser')
        body = soup.find_all('div')
        for tag in body:
            titles.append(tag.text.strip())
    except:
        titles.append("This one is a 403 error ---- " + link)
        pass
    return (titles)




MDFTEST = pd.DataFrame()
for i in d2:
    dictObj =scraper(i)
    MDFTEST = MDFTEST.append(dictObj)

# %%
MDFTEST

# %%
MDFTEST

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup

# %%
def scraper2(link):
    headers = {'user-agent': 'Mozilla/5.0'}
    r = Request(link , headers)
    webpage = urlopen(r).read()
    soup = BeautifulSoup(webpage,'html.parser')
    images = soup.find_all('a')
    
    resolvedURLs = []
    
    for image in images:
        src = image.get('href')
        resolvedURLs.append(requests.compat.urljoin(URL, src))
        
    return

# %%
scraper2('https://www.carolinacarerx.org')

# %%
#########################################

# %%
from bs4 import BeautifulSoup
import requests

html_page = requests.get('http://books.toscrape.com/')
soup = BeautifulSoup(html_page.content, 'html.parser')
warning = soup.find('div', class_="alert alert-warning")
book_container = warning.nextSibling.nextSibling

images = book_container.findAll('img')
example = images[0]
example

# %%
example.attrs['src']

# %%
import shutil

# %%
url_base = "http://books.toscrape.com/" #Original website
url_ext = example.attrs['src'] #The extension you pulled earlier
full_url = url_base + url_ext #Combining first 2 variables to create       a complete URL
r = requests.get(full_url, stream=True) #Get request on full_url
if r.status_code == 200:                     #200 status code = OK
   with open("images/book1.jpg", 'wb') as f: 
      r.raw.decode_content = True
      shutil.copyfileobj(r.raw, f)

# %%
import requests

# %%
URL = 'https://www.carolinacarerx.org/'

page = requests.get(URL)

soup = BeautifulSoup(page.content,'html.parser')

images = soup.find_all('a')

images

# %%
URL = 'https://www.carolinacarerx.org/'

page = requests.get(URL)

soup = BeautifulSoup(page.content,'html.parser')

body = soup.find_all('body')

# %%
def logoscraper(link):
    URL = 'https://www.carolinacarerx.org/'

    page = requests.get(URL)

    soup = BeautifulSoup(page.content,'html.parser')

    images = soup.find_all('a')

    return(images)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpim

# %%
img = mpimg.imread('images/book1.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
import pandas as pd
from IPython.display import Image, HTML
row_1 = [example.attrs['alt'], '<img src="images/book1.jpg"/>']
df = pd.DataFrame(row_1).transpose()
df.columns = ['Title', 'Cover']
HTML(df.to_html(escape=False))

# %%
h = 'https://'
d2 = [h + i for i in datatest2]
titles=[]
def scraper(link):
    try:
        from urllib.request import urlopen
        from bs4 import BeautifulSoup
        htmld = urlopen(link)
        headers = {'user-agent': 'ds6050 (vzw6yk@virginia.edu)'}
        r = requests.get(link, headers=headers)
        soup = BeautifulSoup(htmld,'html.parser')
        body = soup.find_all('div')
        for tag in body:
            titles.append(tag.text.strip())
    except:
        titles.append("This one is a 403 error ---- " + link)
        pass
    return (titles)
MDFTEST2 = pd.DataFrame()
for i in d2:
    dictObj =scraper(i)
    MDFTEST2 = MDFTEST2.append(dictObj)

# %%
d

# %%
MDFTEST2

# %%
import requests
from bs4 import BeautifulSoup
import csv
   
URL = "http://www.values.com/inspirational-quotes"
r = requests.get(URL)
   
soup = BeautifulSoup(r.content, 'html5lib')
   
quotes=[]  # a list to store quotes
   
table = soup.find('div', attrs = {'id':'all_quotes'}) 
   
for row in table.findAll('div',
                         attrs = {'class':'col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top'}):
    quote = {}
    quote['theme'] = row.h5.text
    quote['url'] = row.a['href']
    quote['img'] = row.img['src']
    quote['lines'] = row.img['alt'].split(" #")[0]
    quote['author'] = row.img['alt'].split(" #")[1]
    quotes.append(quote)
   
filename = 'inspirational_quotes.csv'
with open(filename, 'w', newline='') as f:
    w = csv.DictWriter(f,['theme','url','img','lines','author'])
    w.writeheader()
    for quote in quotes:
        w.writerow(quote)

# %%
table

# %%
###### Body Scraper Function

# %%
h = 'https://'
d = [h+i for i in data]

bods= []
def bodyscraper(link):
    try:
        html = urlopen(link)
        headers = {'user-agent': 'Mozilla/5.0'}
        page = requests.get(link,headers)
        soup = BeautifulSoup(page.content,'html.parser')
        body = soup.find_all('body')
        for b in body:
            bods.append(b)
    except:
        bods.append("BINGO:" + link)
        pass
        
    return(bods)

bodies = pd.DataFrame()
for i in d:
    dictObj =bodyscraper(i)
    bodies = bodies.append(dictObj)

bodies

# %%
h = 'https://'
d2 = [h + i for i in datatest2]
titles=[]
def scraper(link):
    try:
        htmld = urlopen(link)
        headers = {'user-agent': 'Mozilla/5.0'}
        r = Request(link, headers=headers)
        soup = BeautifulSoup(htmld,'html.parser')
        body = soup.find_all('div')
        for tag in body:
            titles.append(tag.text.strip())
    except:
        titles.append("This one is a 403 error ---- " + link)
        pass
    return (titles)




MDFTEST = pd.DataFrame()
for i in d2:
    dictObj =scraper(i)
    MDFTEST = MDFTEST.append(dictObj)

# %%
    
    headers = {'user-agent': 'Mozilla/5.0'}
    r = Request(link , headers)
    webpage = urlopen(r).read()
    soup = BeautifulSoup(webpage.content,'html.parser')
    body = soup.find_all('a')

    return (body)
